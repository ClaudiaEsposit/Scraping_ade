# %%
import pandas as pd
import numpy as np

# %%
input0 = pd.read_excel('Input/Raw/Ricerca F24.xlsx')
def split_and_expand(df, column_name):
    df[column_name] = df[column_name].str.split(' - ')
    df_expanded = df.explode(column_name)
    return df_expanded

# %%
input = split_and_expand(input0, 'N° Rep PPT')
input['N. RG'] = (input['N. RG'].str.replace('Rg.', '', regex=False)
                .str.replace('Nr.', '', regex=False)
                .str.replace('-', '/', regex=False)
                .str.strip()
                )
input['N. Decreto'] = (input['N. Decreto'] .str.replace('Nr.', '', regex=False)
                        .str.replace('Rg.', '', regex=False)
                        .str.replace('-', '/', regex=False)
                        .str.strip()
                    )
input['N° Repertorio'] = (input['N° Repertorio'] .str.replace('Nr.', '', regex=False)
                        .str.replace('Rg.', '', regex=False)
                        .str.replace('-', '/', regex=False)
                        .str.strip()
                    )
input['N. Cronologico'] = (input['N. Cronologico'] .str.replace('Nr.', '', regex=False)
                        .str.replace('Rg.', '', regex=False)
                        .str.replace('-', '/', regex=False)
                        .str.strip()
                    )
input['N.R.G.E PPT'] = (input['N.R.G.E PPT'] .str.replace('Nr.', '', regex=False)
                        .str.replace('Rg.', '', regex=False)
                        .str.replace('-', '/', regex=False)
                        .str.strip()
                    )
input['N° Rep PPT'] = (input['N° Rep PPT'] .str.replace('Nr.', '', regex=False)
                        .str.replace('Rg.', '', regex=False)
                        # .str.replace('-', '/', regex=False)
                        .str.strip()
                    )

# %%
input[['nr.rg', 'year.rg']] = input['N. RG'].str.split('/', expand=True)
input[['nr.decreto', 'year.decreto']] = input['N. Decreto'].str.split('/', expand=True)
input[['nr.repertorio', 'year.repertorio']] = input['N° Repertorio'].str.split('/', expand=True)
input[['nr.crono', 'year.crono']] = input['N. Cronologico'].str.split('/', expand=True)
input[['nr.rgeppt', 'year.rgeppt']] = input['N.R.G.E PPT'].str.split('/', expand=True)
input[['nr.repppt', 'year.repppt']] = input['N° Rep PPT'].str.split('/', expand=True)
input = input.drop(columns=['N. RG','N. Decreto','N° Repertorio','N. Cronologico','N.R.G.E PPT','N° Rep PPT'])

# %%
def update_year(year):
    if pd.isna(year):
        return year
    year = int(year)

    if year < 100:
        if 0 <= year <= 24:
            return 2000 + int(year)
        else:
            return 1900 + int(year)
    return (year)

# List of columns to update
year_columns = [col for col in input.columns if col.startswith('year')]

# Apply the function to the relevant columns
for col in year_columns:
    input[col] = input[col].apply(update_year)
    input[col] = input[col].astype(str).str.split('.').str[0]

input.replace('nan', np.nan, inplace=True)

# %%
input[input['year.rg'].isna()]
# Out:
#                NR_Contratto             Debitore Tribunale/Gdp      Foro  \
# 16        AKCO100458843.001         TOSI ROBERTO    Tribunale    MILANO
# 17         AKCO12501994.074        MELIS LUCIANO    Tribunale   CAGLIARI
# 18        AKCO300232751.001     SCIFO SEBASTIANO    Tribunale   SIRACUSA
# 19     EN824247076_25012016   D'ANGELI SALVATORE    Tribunale   SIRACUSA
# 19     EN824247076_25012016   D'ANGELI SALVATORE    Tribunale   SIRACUSA
# 20  EN926000168142_18012016  DI STEFANO ADELAIDE    Tribunale   SIRACUSA
# 20  EN926000168142_18012016  DI STEFANO ADELAIDE    Tribunale   SIRACUSA
#
#    RICERCA IQERA    Cliente nr.rg year.rg nr.decreto year.decreto  \
# 16           PPT  AK NORDIC   NaN     NaN        NaN          NaN
# 17           PPT  AK NORDIC   NaN     NaN        NaN          NaN
# 18           PPT  AK NORDIC   NaN     NaN        NaN          NaN
# 19           PPT        ENI   NaN     NaN        NaN          NaN
# 19           PPT        ENI   NaN     NaN        NaN          NaN
# 20           PPT        ENI   NaN     NaN        NaN          NaN
# 20           PPT        ENI   NaN     NaN        NaN          NaN
#
#    nr.repertorio year.repertorio nr.crono year.crono nr.rgeppt year.rgeppt  \
# 16           NaN             NaN      NaN        NaN     10332        2019
# 17           NaN             NaN      NaN        NaN       120        2021
# 18           NaN             NaN      NaN        NaN       593        2018
# 19           NaN             NaN      NaN        NaN       530        2019
# 19           NaN             NaN      NaN        NaN       530        2019
# 20           NaN             NaN      NaN        NaN      1139        2019
# 20           NaN             NaN      NaN        NaN      1139        2019
#
#    nr.repppt year.repppt
# 16       NaN         NaN
# 17       NaN         NaN
# 18       NaN         NaN
# 19       838        2019
# 19      3357        2019
# 20      4449        2019
# 20      1102        2019

# %%
input
# Out:
#                NR_Contratto                    Debitore Tribunale/Gdp  \
# 0         AKCO300582766.001              CHIAVETTA CONO    Tribunale
# 1         AKCO300611623.001            ARIGO' PANCRAZIO    Tribunale
# 2               CRS18966047     SCANZIANI MARIA JOSELLA    Tribunale
# 3                CRS2294452           NUNNERI FRANCESCO    Tribunale
# 4          AKCO890006504896               GERARDO MASSA    Tribunale
# 5                CRS5606632            CIOTOLA PASQUALE    Tribunale
# 6         AKCO300425648.001           RUSCICA SALVATORE    Tribunale
# 7        TBCO0011975804.074         SORRENTINO PATRIZIO    Tribunale
# 8               TBS25618238        GIRUZZI FABRIZIO MAX    Tribunale
# 9               TBS31289295                MARSALA IVAN    Tribunale
# 10        AKCO100458843.001                TOSI ROBERTO    Tribunale
# 11     EN805704285_08052014  BENVENUTO ALBERTO RICCARDO       Giudice
# 12     EN806278669_08052014              FIORE LOREDANA       Giudice
# 13           AKCO3101129684             SILVIO MORGILLO       Giudice
# 14        AKCO400560072.001             RENES CARMELINA    Tribunale
# 15     EN801613670_20012015        BRUSCOLOTTI GIUSEPPE       Giudice
# 16        AKCO100458843.001                TOSI ROBERTO    Tribunale
# 17         AKCO12501994.074               MELIS LUCIANO    Tribunale
# 18        AKCO300232751.001            SCIFO SEBASTIANO    Tribunale
# 19     EN824247076_25012016          D'ANGELI SALVATORE    Tribunale
# 19     EN824247076_25012016          D'ANGELI SALVATORE    Tribunale
# 20  EN926000168142_18012016         DI STEFANO ADELAIDE    Tribunale
# 20  EN926000168142_18012016         DI STEFANO ADELAIDE    Tribunale
#
#               Foro RICERCA IQERA    Cliente  nr.rg year.rg nr.decreto  \
# 0         SIRACUSA     MONITORIA  AK NORDIC   7062    2017        588
# 1         SIRACUSA     MONITORIA  AK NORDIC   5067    2017       1931
# 2           MONZA      MONITORIA   MBCREDIT   6996    2019       4293
# 3           NAPOLI     MONITORIA   MBCREDIT  14685    2020       7521
# 4          SALERNO     MONITORIA  AK NORDIC    276    2017        343
# 5           NAPOLI     MONITORIA   MBCREDIT  10557    2021       4139
# 6         SIRACUSA     MONITORIA  AK NORDIC   1685    2017       1158
# 7           NAPOLI     MONITORIA   TIBERIUS  35958    2018         95
# 8            MONZA     MONITORIA   TIBERIUS  12410    2018        987
# 9         SIRACUSA     MONITORIA   TIBERIUS   6622    2018        514
# 10         MILANO      MONITORIA  AK NORDIC  35950    2018      19554
# 11         GENOVA      MONITORIA        ENI   7507    2015        428
# 12           PARMA     MONITORIA        ENI   5586    2014       1840
# 13          ACERRA     MONITORIA  AK NORDIC   3277    2016       1063
# 14         POTENZA     MONITORIA  AK NORDIC    138    2017        142
# 15  SALA CONSILINA     MONITORIA        ENI    185    2019         69
# 16         MILANO            PPT  AK NORDIC    NaN     NaN        NaN
# 17        CAGLIARI           PPT  AK NORDIC    NaN     NaN        NaN
# 18        SIRACUSA           PPT  AK NORDIC    NaN     NaN        NaN
# 19        SIRACUSA           PPT        ENI    NaN     NaN        NaN
# 19        SIRACUSA           PPT        ENI    NaN     NaN        NaN
# 20        SIRACUSA           PPT        ENI    NaN     NaN        NaN
# 20        SIRACUSA           PPT        ENI    NaN     NaN        NaN
#
#    year.decreto nr.repertorio year.repertorio nr.crono year.crono nr.rgeppt  \
# 0          2018          2263            2019     8245       2019       NaN
# 1          2017          1981            2018     7606       2018       NaN
# 2          2019           853            2021     1245       2021       NaN
# 3          2020          3900            2021     4421       2021       NaN
# 4          2017          5966            2022     2844       2022       NaN
# 5          2021         10451            2021    11639       2021       NaN
# 6          2017          1990            2018     7619       2018       NaN
# 7          2019          9241            2021    10142       2021       NaN
# 8          2019          1805            2020     2526       2020       NaN
# 9          2019          2788            2019     9919       2019       NaN
# 10         2018           NaN             NaN      NaN        NaN       NaN
# 11         2016           NaN             NaN      NaN        NaN       NaN
# 12         2013           NaN             NaN      NaN        NaN       NaN
# 13         2016           NaN             NaN      NaN        NaN       NaN
# 14         2017           NaN             NaN      NaN        NaN       NaN
# 15         2019           NaN             NaN      NaN        NaN       NaN
# 16          NaN           NaN             NaN      NaN        NaN     10332
# 17          NaN           NaN             NaN      NaN        NaN       120
# 18          NaN           NaN             NaN      NaN        NaN       593
# 19          NaN           NaN             NaN      NaN        NaN       530
# 19          NaN           NaN             NaN      NaN        NaN       530
# 20          NaN           NaN             NaN      NaN        NaN      1139
# 20          NaN           NaN             NaN      NaN        NaN      1139
#
#    year.rgeppt nr.repppt year.repppt
# 0          NaN       NaN         NaN
# 1          NaN       NaN         NaN
# 2          NaN       NaN         NaN
# 3          NaN       NaN         NaN
# 4          NaN       NaN         NaN
# 5          NaN       NaN         NaN
# 6          NaN       NaN         NaN
# 7          NaN       NaN         NaN
# 8          NaN       NaN         NaN
# 9          NaN       NaN         NaN
# 10         NaN       NaN         NaN
# 11         NaN       NaN         NaN
# 12         NaN       NaN         NaN
# 13         NaN       NaN         NaN
# 14         NaN       NaN         NaN
# 15         NaN       NaN         NaN
# 16        2019       NaN         NaN
# 17        2021       NaN         NaN
# 18        2018       NaN         NaN
# 19        2019       838        2019
# 19        2019      3357        2019
# 20        2019      4449        2019
# 20        2019      1102        2019

# %%
uffici = pd.read_excel('../Resources/uffici_finanziari.xlsx')
uffici = uffici.iloc[1:]
uffici['office'] = uffici['office'].str.lower().tolist()
uffici_ut = uffici[uffici['office'].str.contains('ut')]

# %%
import json

with open('../Resources/enti_completi_ut.json', 'r') as file:
    enti = json.load(file)

enti
# Out:
# {'abbiategrasso  ut dpmi1': ['001 - TRIBUNALE', '002 - GIUDICE DI PACE'],
#  'acireale  ut dpct': ['001 - TRIBUNALE DI ACIREALE',
#   '002 - GIUDICE DI PACE ACIREALE',
#   '003 - GIUDICE DI PACE TRECASTAGNI'],
#  'acqui terme  ut dpal': ['001 - PRETURA ACQUI TERME',
#   '002 - TRIBUNALE ACQUI TERME',
#   '003 - GIUDICE DI PACE ACQUI TERME',
#   '004 - GIUDICE DI PACE DI OVADA'],
#  'adria  ut dpro': ['001 - PRETURA DI ADRIA',
#   '002 - GIUDICE DI PACE DI ADRIA',
#   '003 - TRIB.LE ROVIGO - SEZ. DI ADRIA'],
#  'agrigento  ut dpag': ['001 - TRIBUNALE AGRIGENTO',
#   '002 - GIUDICE DI PACE ARAGONA',
#   '003 - GIUDICE DI PACE DI AGRIGENTO',
#   '004 - GIUDICE DI PACE DI BIVONA',
#   '005 - GIUDICE DI PACE DI CAMMARATA',
#   '006 - GIUDICE DI PACE DI CASTELTERMI',
#   '007 - GIUD. PACE CATTOLICA ERACLEA',
#   '008 - PRETURA AGRIGENTO',
#   '009 - PRETURA DI CAMMARATA',
#   '010 - PRETURA DI CASTELTERMINI',
#   '011 - PRETURA DI ARAGONA',
#   '012 - PRETURA DI BIVONA',
#   '013 - PRETURA DI FAVARA',
#   '014 - PRETURA DI CATTOLICA ERACLEA',
#   '015 - GIUDICE PACE DI FAVARA',
#   '016 - TRIB. AG - SEZ. STRALCIO'],
#  'agropoli  ut dpsa': ['001 - PRETURA DI AGROPOLI',
#   '002 - GIUDICE DI PACE DI AGROPOLI',
#   '003 - PRETURA DI CAPACCIO',
#   '004 - GIUDICE DI PACE DI CAPACCIO'],
#  'alba  ut dpcn': ['001 - TRIBUNALE DI ALBA',
#   '002 - GIUDICE DI PACE DI CANALE',
#   '003 - GIUDICE DI PACE S.STEFANO',
#   '004 - GIUDICE DI PACE DI ALBA',
#   '005 - TRIBUNALE DI ALBA SEZ. BRA',
#   '006 - GIUDICE DI PACE DI BRA'],
#  'albano laziale  ut dprm3': ['001 - TRIBUNALE ALBANO LAZIALE',
#   '002 - GIUDICE DIB PACE DI ALBANO',
#   '003 - GIUDICE DI PACE DI GENZANO',
#   '004 - AERONAUTICA MILITARE CIAMPINO',
#   '005 - TRIB ALB LAZ',
#   '006 - TRIBUNALE DI ALBANO LAZIALE',
#   '007 - TRIB ALBANO LAZIALE'],
#  'alessandria  ut dpal': ['001 - PRETURA',
#   '002 - TRIBUNALE',
#   '003 - GIUDICE DI PACE',
#   '004 - UFFICIO UNICO TRIBUNALE ALES.',
#   '005 - 80005400066',
#   '006 - GIUDICE DI PACE DI VALENZA'],
#  'ancona  ut dpan': ['001 - CORTE DI APPELLO DI ANCONA',
#   '002 - TRIBUNALE DI ANCONA',
#   '003 - PRETURA CIRCONDARIALE ANCONA',
#   '004 - PRETURA CIRC.SEZ.STACC. OSIMO',
#   '005 - GIUDICE DI PACE DI ANCONA',
#   '006 - GIUDICE DI PACE DI OSIMO',
#   '007 - TRIBUNALE PER MINORENNI ANCONA',
#   '008 - TRIBUNALE AN SEZ.STAC.OSIMO',
#   '009 - T.A.R. ANCONA',
#   '010 - TRIBUNALE DI SORVEGLIANZA AN'],
#  'aosta  ut drao': ['001 - PRETURA',
#   '002 - GIUDICE DI PACE',
#   '003 - TRIBUNALE',
#   '004 - TRIBUNALE DI AOSTA',
#   '005 - GIUDICE DI PACE DI AOSTA',
#   "006 - T.A.R. REGIONE VALLE D'AOSTA"],
#  'arezzo ut dpar': ['001 - TRIBUNALE DI AREZZO',
#   '002 - GIUDICE DI PACE DI AREZZO',
#   '003 - GIUDICE DI PACE - CORTONA',
#   '004 - GIUDICE DI PACE - BIBBIENA',
#   '005 - TRIB. AREZZO SEZ. SANSEPOLCRO',
#   '006 - GDP AREZZO-EX GDP S.G. VALD.'],
#  'ariano irpino  ut dpav': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE ARIANO IRPINO',
#   '003 - GIUDICE DI PACE CASTEL BARONIA',
#   '004 - GIUDICE DI PACE FRIGENTO',
#   '005 - GIUDICE DI PACE GROTTAMINARDA',
#   '006 - GIUDICE DI PACE MIRABELLA ECL.',
#   '007 - U.N.E.P. TRIBUNALE DI ARIANO I',
#   '008 - TRIBUNALE S.ANGELO LOMBARDI',
#   '009 - PRETURA S.ANGELO DEI LOMBARDI',
#   '010 - GIUDICE DI PACE LACEDONIA',
#   '011 - GIUDICE DI PACE CALABRITTO',
#   '012 - GIUDICE DI PACE S.ANGELO L.',
#   '013 - GIUDICE DI PACE CALITRI',
#   '014 - GIUDICE DI PACE MONTELLA',
#   '015 - PRETURA MONTELLA',
#   '016 - PRETURA CALITRI',
#   '017 - GDP AR.IRP.-EX GDP GROTTAMIN.',
#   '018 - GDP AR.IRP.-EX GDP CAS. BARON.',
#   '019 - GDP S.A. LOM-EX GDP CALITRI',
#   '020 - GDP S.A.LOM.EX GDP MONTELLA',
#   '021 - GDP S.A. DEI LOMB. EX FRIGENTO',
#   '022 - GDP S.A.DEI LOMB EX CALABRITTO'],
#  'arona  ut dpno': ['001 - GIUDICE DI PACE ARONA',
#   '002 - CANCELLERIA DEL TRIBUNALE',
#   '003 - GIUDICE DI PACE'],
#  'arzignano  ut dpvi': ['001 - GIUDICE DI PACE DI ARZIGNANO'],
#  'ascoli piceno  ut dpap': ['001 - TRIBUNALE DI ASCOLI PICENO',
#   '002 - PRETURA ASCOLI PICENO',
#   '003 - GIUD. PACE ASCOLI PICENO',
#   '004 - GIUD.PACE DI AMANDOLA',
#   '005 - PRETURA CIRCONDARIALE AP',
#   '006 - 92033570448',
#   '007 - UFFICIALE GIUDIZIARIO A.P.',
#   '008 - GIUDICE DI PACE DI OFFIDA',
#   '009 - GDP A.PICENO-EX GDP OFFIDA',
#   '010 - GDP A.PIC-EX GDP S.B.TRONTO'],
#  'asti  ut dpat': ['001 - TRIBUNALE CIVILE DI ASTI',
#   '002 - GIUDICE DI PACE DI ASTI',
#   '003 - GIUDICE DI PACE DI MONCALVO',
#   '004 - UFFICIO DEL GIUDICE DI PACE',
#   '005 - PRETURA DI NIZZA MONFERRATO',
#   '006 - GIUD. DI PACE NIZZA MONFERRATO',
#   '007 - GIUDICE DI PACE CANELLI'],
#  'atri  ut dpte': ['001 - TRIB. DI TERAMO S.S. ATRI',
#   '002 - GIUDICE DI PACE DI ATRI',
#   '003 - GIUDICE DI PACE DI NOTARESCO',
#   '004 - PRETURA DI ATRI',
#   '005 - PRETURA DI NOTARESCO',
#   '006 - GIUDICE DI PACE NOTARESCO'],
#  'augusta  ut dpsr': ['001 - PRETURA DI AUGUSTA',
#   '002 - GIUDICE DI PACE AUGUSTA',
#   '003 - TRIB. SR SEZ. STACC. AUGUSTA',
#   '004 - ISTITUTO VENDITE GIUDIZIARIE'],
#  'aulla  ut dpms': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE DI AULLA',
#   '003 - GIUDICE DI PACE DI PONTREMOLI'],
#  'avellino  ut dpav': ['001 - EX. PRETURA TRIB.AVELLINO',
#   '002 - TRIBUNALE DI AVELLINO',
#   '003 - UFFICIO GIUDICE DI PACE AV.',
#   '004 - UFFICIO G.PACE CERVINARA',
#   '005 - UFFICIO G.PACE MONTORO',
#   '006 - UFFICIO G.PACE LAURO',
#   '007 - PRETURA DI CERVINARA',
#   '008 - GIUDICE DI PACE CHIUSANO S.D.',
#   '009 - TRIB.AV.SEZ.DISTACC.CERVINARA',
#   '010 - TRIB.AV-SEZ.DIST. S.A.LOMBARDI',
#   '011 - GIUDICE DI PACE S.A. LOMBARDI',
#   '012 - GIUDICE DI PACE DI CALABRITTO',
#   '013 - GIUDICE DI PACE DI LACEDONIA'],
#  'aversa  ut dpce': ['001 - PRETURA DI AVERSA',
#   '002 - PRETURA DI TRENTOLA',
#   '003 - TRIB. S.M.C.V. SEZ.STAC.AVERSA',
#   '004 - TRIB.S.M.C.V.SEZ STAC TRENTOLA',
#   '005 - GIUDICE DI PACE - AVERSA',
#   '006 - GIUDICE DI PACE - TRENTOLA D.',
#   '007 - TRIBUNALE DI NAPOLI NORD',
#   '008 - TRIB.NA.NORD UF.NOTIF.PROTESTI',
#   '009 - GDP NAP.NORD-EX GDP AVERSA'],
#  'avezzano  ut dpaq': ['001 - TRIBUNALE',
#   '002 - PRETURA DI AVEZZANO',
#   '003 - PRETURA CELANO',
#   '004 - PRETURA CIVITELLA ROVETO',
#   '005 - GIUDICE DI PACE AVEZZANO',
#   '006 - GIUDICE DI PACE PESCINA',
#   '007 - GIUDICE DI PACE CELANO',
#   '008 - PRETURA TAGLIACOZZO',
#   '009 - GIUDICE DI PACE CIVITELLA ROVE',
#   '010 - GIUDICE DI PACE TAGLIACOZZO',
#   '011 - TRIBUNALE AVEZZANO',
#   '012 - UFFICIALE GIUDIZIARIO AVEZZANO',
#   '013 - 11',
#   '014 - U.N.E.P. DI AVEZZANO',
#   '015 - TRIB. AVEZZANO',
#   '016 - GDP AVEZZANO EX GDP CELANO',
#   '017 - GDP AVEZZANO- EX GDP CIV. ROV.',
#   '018 - GDP AVEZZANO -EX GDP PESCINA',
#   '019 - GDP AVEZZANO -EX GDP TAGLIAC.'],
#  'badia polesine  ut dpro': ['001 - GIUDICE DI PACE DI LENDINARA',
#   '002 - GIUDICE DI PACE DI FICAROLO'],
#  'bagheria  ut dppa': ['001 - TRIBUNALE',
#   '002 - TRIBUNALE DI BAGHERIA',
#   '003 - GIUDICE DI PACE',
#   '004 - TRIBUNALE DI BAGHERIA',
#   '005 - TRIBUNALE DI BAGHERIA',
#   '006 - TRIBUNALE DI BAGHERIA'],
#  'barcellona pozzo di gotto  ut dpme': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE DI BARCELLONA',
#   '003 - GIUDICE PACE NOVARA SICILIA',
#   '004 - TRIB. B.P.G. - EX SEZ. MILAZZO',
#   '005 - TRIB. B.P.G. - EX SEZ. LIPARI',
#   '006 - GDP BAR.P.G.-EX GDP MILAZZO',
#   '007 - GIUDICE DI PACE DI ROMETTA',
#   '008 - GIUDICE DI PACE LIPARI',
#   '009 - UNEP B.P.G.- SEZ. LIPARI',
#   '010 - TRIBUNALE DI PATTI',
#   '011 - GIUDICE DI PACE DI PATTI',
#   '012 - GIUDICE DI PACE DI S.ANGELO B.',
#   '013 - TRIB.PATTI - EX SEZ. MISTRETTA',
#   '014 - TRIB.PATTI - EX S.A. MILITELLO',
#   '015 - GDP PAT-EX GDP S.AG. MILIT.',
#   '016 - TRIBUNALE DI BARCELLONA P.G.',
#   '017 - GDP PATTI-EX GDP TORTORICI'],
#  'bari  ut dpba': ['001 - TRIBUNALE',
#   '002 - PRETURA DI BARI',
#   '003 - TRIBUNALE DI BARI',
#   '004 - CORTE DI APPELLO DI BARI',
#   '005 - PRETURA DI BITONTO',
#   '006 - PRETURA DI CASAMASSIMA',
#   '007 - PRETURA DI MODUGNO',
#   '008 - PRETURA DI MOLFETTA',
#   '009 - PRETURA DI MONOPOLI',
#   '010 - PRETURA DI RUTIGLIANO',
#   '011 - PRETURA DI RUVO DI PUGLIA',
#   '012 - GIUDICE DI PACE DI BARI',
#   '013 - GIUDICE DI PACE DI BITONTO',
#   '014 - GIUDICE DI PACE DI CASAMASSIMA',
#   '015 - GIUDICE DI PACE DI MODUGNO',
#   '016 - GIUDICE DI PACE DI MOLFETTA',
#   '017 - GIUDICE DI PACE DI MONOPOLI',
#   '018 - GIUDICE DI PACE DI RUTIGLIANO',
#   '019 - GIUDICE DI PACE RUVO DI PUGLIA',
#   '020 - ISTITUTO VENDITE GIUDIZIARIE',
#   '021 - ESATTORIA COMUNALE DI BARI',
#   '022 - TRIBUNALE MINORENNI DI BARI',
#   '023 - TRIBUNALE DI BARI SEZ. BITONTO',
#   '024 - TRIBUNALE DI BARI SEZ. MODUGNO',
#   '025 - TRIBUNALE DI BARI SEZ.MOLFETTA',
#   '026 - TRIBUNALE BARI SEZ.MONOPOLI',
#   '027 - TRIBUNALE BARI SEZ. RUTIGLIANO',
#   '028 - TRIBUNALE BARI SEZ. RUVO',
#   '029 - TRIBUNALE BARI EX PRETURA BARI',
#   '030 - TRIBUNALE BARI - SEZ. STRALCIO',
#   '031 - T.A.R. PUGLIA',
#   '032 - GIUDICE DI PACE DI CORATO',
#   '033 - GDP BARI - EX GDP ACQ.D.FONTI',
#   '034 - GDP BARI - EX GDP BITONTO',
#   '035 - GDP BARI-EX GDP CASAMASSIMA',
#   '036 - GDP BARI- EX GDP GIOIA D.COLLE',
#   '037 - GDP BARI-EX GDP MODUGNO',
#   '038 - GDP BARI-EX GDP RUTIGLIANO'],
#  'barletta  ut dpbt': ['001 - PRETURA DI BARLETTA',
#   '002 - TRIB. TRANI - SEZ. BARLETTA',
#   '003 - TRIB. TRANI - SEZ. CANOSA',
#   '004 - TRIB TRANI - SEZ. ANDRIA',
#   '005 - TRIB. TRANI - SEZ MINERVINO',
#   '006 - GIUDICE DI PACE BARLETTA',
#   '007 - GIUDICE DI PACE ANDRIA',
#   '008 - GIUDICE DI PACE CANOSA',
#   '009 - GIUDICE DI PACE MINERVINO',
#   '010 - UFFICIO REGISTRO BARLETTA',
#   '011 - TRIB. FG SEZ. TRINITAPOLI',
#   '012 - GIUDICE DI PACE TRINITAPOLI'],
#  'bassano del grappa  ut dpvi': ['001 - TRIBUNALE',
#   '002 - PRETURA',
#   '003 - GIUDICE DI PACE',
#   '004 - TRIBUNALE',
#   '005 - GIUDICE DI PACE DI THIENE',
#   '006 - GIUDICE DI PACE DI ASIAGO',
#   '007 - PRETURA DI THIENE',
#   '008 - PRETURA DI ASIAGO'],
#  'belluno  ut dpbl': ['001 - TRIBUNALE BELLUNO',
#   '002 - GIUDICE DI PACE DI BELLUNO',
#   '003 - PRETURA DI BELLUNO',
#   '004 - GIUDICE DI PACE DI AGORDO',
#   '005 - GIUDICE DI PACE PIEVE DI CAD.',
#   '006 - TRIB.BL-SEZ.DIST.PIEVE CADORE',
#   "007 - GIUDICE DI PACE CORTINA D'AMP",
#   '008 - GIUDICE DI PACE DI CORTINA',
#   '009 - GDP BELLUNO - EX GDP FELTRE'],
#  'benevento  ut dpbn': ['001 - GIUDICE DI PACE BENEVENTO',
#   '002 - GIUDICE DI PACE S.GIORGIO S.',
#   '003 - TRIBUNALE BENEVENTO',
#   '004 - GIUDICE DI PACE DI VITULANO',
#   '005 - TRIBUNALE DI AIROLA',
#   '006 - GIUDICE PACE DI MONTESARCHIO',
#   '007 - GIUDICE PACE COLLE SANNITA',
#   '008 - GIUDICE PACE S. GIORGIO LA M.',
#   '009 - GIUD.PACE S.AGATA DEI GOTI',
#   '010 - TRIB.BN(EX TRIB.ARIANO IRPINO)',
#   '011 - GIUDICE PACE AIROLA',
#   '012 - GIUDICE PACE SOLOPACA',
#   '013 - TRIB.ORD.BN SEZ.STAC.GUARDIA S',
#   '014 - GIUDICE PACE CERRETO SANNITA',
#   '015 - GIUDICE DI PACE GUARDIA S.',
#   '016 - TRIBUNALE BENEVENTO',
#   '017 - GDP BEN. EX GDP S.G.SANN'],
#  'bergamo 1  ut dpbg': ['001 - TRIBUNALE DI BERGAMO',
#   '002 - PRETURA DI BERGAMO',
#   '003 - GIUDICE DI PACE DI BERGAMO',
#   '004 - PRETURA DI ALMENNO S. S',
#   '005 - PRETURA GRUMELLO',
#   '006 - GIUDICE PACE ALMENNO',
#   '007 - GIUDICE DI PACE GRUMELLO',
#   '008 - TRIBUNALE DI GRUMELLO',
#   '009 - GDP BERG.-EX GDP ALM. S.SALV.',
#   '010 - GDP BERGAMO-EX GDP CLUSONE',
#   '011 - GDP GRUM.D.MON.-EX GDP LOVERE',
#   '012 - GDP BERGAMO-EX GDP ZOGNO'],
#  'bergamo 2  ut dpbg': ['001 - GIUDICE DI PACE DI ZOGNO'],
#  'biella  ut dpbi': ['001 - PRETURA DI BIELLA',
#   '002 - TRIBUNALE DI BIELLA',
#   '003 - GIUDICE DI PACE',
#   '004 - TRIBUNALE SEZ. STRALCIO'],
#  'bologna 2  ut dpbo': ['001 - TRIBUNALE',
#   '002 - CORTE DI APPELLO',
#   '003 - PRETURA 1',
#   '004 - PRETURA 2',
#   '005 - PRETURA 3',
#   '006 - GIUDICE DI PACE',
#   '007 - T.A.R.',
#   '008 - CORTE APP. VOL. GIUR.',
#   '009 - TRIBUNALE VOL. GIUR.',
#   '010 - G.PACE S.GIOVANNI IN PERSICETO',
#   '011 - TRIBUNALE PORRETTA TERME',
#   '012 - GIUDICE DI PACE PORRETTA TERME',
#   '013 - GIUDICE DI PACE VERGATO',
#   '014 - TRIBUNALE MINORI BOLOGNA',
#   '015 - GIUDICE DI PACE BUDRIO',
#   '016 - PRETURA DI BUDRIO'],
#  'bologna 3  ut dpbo': ['001 - TRIBUNALE',
#   '002 - CORTE DI APPELLO',
#   '003 - PRETURA 1',
#   '004 - PRETURA 2',
#   '005 - PRETURA 3',
#   '006 - GIUDICE DI PACE',
#   '007 - T.A.R.',
#   '008 - CORTE APP. VOL. GIUR.',
#   '009 - TRIBUNALE VOL. GIUR.',
#   '010 - G.PACE S.GIOVANNI IN PERSICETO',
#   '011 - TRIBUNALE PORRETTA TERME',
#   '012 - GIUDICE DI PACE PORRETTA TERME',
#   '013 - GIUDICE DI PACE VERGATO',
#   '014 - TRIBUNALE MINORI BOLOGNA',
#   '015 - GIUDICE DI PACE BUDRIO',
#   '016 - PRETURA DI BUDRIO'],
#  'bolzano  ut dpbz': ['001 - TRIBUNALE DI BOLZANO',
#   '002 - PRETURA DI BOLZANO',
#   '003 - GIUDICE DI PACE SEZ. BOLZANO',
#   '004 - CORTE DI APPELLO SEZ. BOLZANO',
#   '005 - TRIBUNALE MINORI SEZ. BOLZANO',
#   '006 - GIUDICE DI PACE SEZ. CHIUSA',
#   '007 - GIUDICE DI PACE SEZ. CALDARO',
#   '008 - GIUDICE DI PACE DI EGNA',
#   '009 - T.A.R. DI BOLZANO'],
#  'bolzano ut aapp succ rimb iva  dpbz': ['001 - TRIBUNALE DI BOLZANO',
#   '002 - PRETURA DI BOLZANO',
#   '003 - GIUDICE DI PACE SEZ. BOLZANO',
#   '004 - CORTE DI APPELLO SEZ. BOLZANO',
#   '005 - TRIBUNALE MINORI SEZ. BOLZANO',
#   '006 - GIUDICE DI PACE SEZ. CHIUSA',
#   '007 - GIUDICE DI PACE SEZ. CALDARO',
#   '008 - GIUDICE DI PACE DI EGNA',
#   '009 - T.A.R. DI BOLZANO',
#   '010 - TRIBUNALE SEZ. BRESSANONE',
#   '011 - UFF.GIUDICE PACE BRESSANONE',
#   '012 - UFF.GIUD.PACE BRUNICO',
#   '013 - UFF.GIUD.PACE VIPITENO',
#   '014 - UFF.GIUD.PACE MONGUELFO',
#   '015 - PRETURA BRUNICO',
#   '016 - PRETURA VIPITENO',
#   '017 - PRETURA BRESSANONE',
#   '018 - TRIBUNALE SEZ. BRUNICO',
#   '019 - GIUDICE DI PACE DI MERANO',
#   '020 - GIUDICE DI PACE DI SILANDRO',
#   '021 - TRIBUNALE DI MERANO'],
#  'borgo san lorenzo  ut dpfi': ['001 - PRETURA DI BORGO SAN LORENZO',
#   '002 - GIUDICE DI PACE DI B.S.LORENZO',
#   '003 - CCCBRC65C47I726H',
#   '004 - GIUDICE DI PACE'],
#  'borgo valsugana  ut dptn': ['001 - TRIB. TRENTO SEZ. BORGO',
#   '002 - TRIB.TRENTO SEZ. BORGO',
#   '003 - GIUDICE DI PACE DI BORGO',
#   '004 - GIUDICE DI PACE DI FIERA'],
#  'borgomanero  ut dpno': ['001 - TRIBUNALE DI NOVARA',
#   '002 - GIUDICE DI PACE BORGOMANERO',
#   '003 - GIUDICE DI PACE DI ARONA',
#   '004 - TRIBUNALE BORGOMANERO'],
#  'borgosesia  ut dpvc': ['001 - COMUNITA MONTANA VALSESIA',
#   "002 - UNIONE DEI COMUNI 'VAL PITTA'",
#   '003 - GIUDICE DI PACE DI VARALLO',
#   '004 - TRIBUNALE DI VARALLO',
#   '005 - UNIONE DEI COMUNI VAL PITTA',
#   '006 - CO.R.D.A.R. VARALLO-CIVIASCO'],
#  'bra  ut dpcn': ['001 - TRIBUNALE DI ALBA SEZ. BRA',
#   '002 - GIUDICE DI PACE DI BRA',
#   '003 - SEGRETARIO SOMMARIVA PERNO'],
#  'breno  ut dpbs': ['001 - TRIBUNALE ORDINARIO DI BRESCIA',
#   '002 - GIUDICE DI PACE-BRENO',
#   '003 - TRIB.LE SEZ.NE STAC. DI BRENO',
#   '004 - U.N.E.P.- TRIBUNALE'],
#  'brescia  ut dpbs': ['001 - TRIBUNALE DI BRESCIA',
#   "002 - CORTE D'APPELLO DI BRESCIA",
#   '003 - GIUDICE DI PACE DI BRESCIA',
#   '004 - TRIBUNALE MINORENNI DI BRESCIA',
#   '005 - GIUDICE DI PACE DI ISEO',
#   '006 - GIUDICE DI PACE DI ORZINUOVI',
#   '007 - TAR LOMBARDIA SEZ.STACC. DI BS',
#   '008 - I.V.G. DI BRESCIA',
#   '009 - UFFICIALI GIUDIZIARI DI BSI',
#   '010 - STRALCIO PRETURA DI BRESCIA',
#   '011 - TRIBUNALE SORVEGLIANZA',
#   '012 - GDP BRESCIA-EX GDP BRENO',
#   '013 - GDP BRES.-EX GDP GAR.V.TRO.',
#   '014 - GDP BRESCIA-EX GDP ISEO',
#   '015 - GDP BRESCIA-EX GDP LONATO',
#   '016 - GDP BRESCIA-EX GDP MONTICH.',
#   '017 - GDP BRESCIA-EX GDP ORZINUOVI',
#   "018 - GDP BRESCIA-EX GDP SALO'",
#   '019 - GDP BRESCIA-EX GDP VEROLAN.'],
#  'brescia 1  ut dpbs': ['001 - TRIBUNALE DI BRESCIA',
#   "002 - CORTE D'APPELLO DI BRESCIA",
#   '003 - GIUDICE DI PACE DI BRESCIA',
#   '004 - TRIBUNALE MINORENNI DI BRESCIA',
#   '005 - GIUDICE DI PACE DI ISEO',
#   '006 - GIUDICE DI PACE DI ORZINUOVI',
#   '007 - TAR LOMBARDIA SEZ.STACC. DI BS',
#   '008 - I.V.G. DI BRESCIA',
#   '009 - UFFICIALI GIUDIZIARI DI BSI',
#   '010 - STRALCIO PRETURA DI BRESCIA',
#   '011 - TRIBUNALE SORVEGLIANZA',
#   '012 - GDP BRESCIA-EX GDP BRENO',
#   '013 - GDP BRES.-EX GDP GAR.V.TRO.',
#   '014 - GDP BRESCIA-EX GDP ISEO',
#   '015 - GDP BRESCIA-EX GDP LONATO',
#   '016 - GDP BRESCIA-EX GDP MONTICH.',
#   '017 - GDP BRESCIA-EX GDP ORZINUOVI',
#   "018 - GDP BRESCIA-EX GDP SALO'",
#   '019 - GDP BRESCIA-EX GDP VEROLAN.'],
#  'bressanone-brunico  ut dpbz': ['001 - TRIBUNALE',
#   '002 - UFF.GIUDICE PACE BRESSANONE',
#   '003 - UFF.GIUD.PACE BRUNICO',
#   '004 - UFF.GIUD.PACE VIPITENO',
#   '005 - UFF.GIUD.PACE MONGUELFO',
#   '006 - PRETURA BRUNICO',
#   '007 - PRETURA VIPITENO',
#   '008 - PRETURA BRESSANONE',
#   '009 - TRIBUNALE SEZ. BRESSANONE',
#   '010 - TRIBUNALE SEZ. BRUNICO',
#   '011 - GIUDICE DI PACE CHIUSA',
#   '012 - 80002280214',
#   '013 - SEZ. STACC. BRUNICO TRIB. BZ',
#   '014 - UFF. GIUDICE PACE BRUNICO',
#   '015 - UFF.GIUDICE PACE BRUNICO',
#   '016 - 80003690221',
#   '017 - UFF. GIUDICE PACE MONGUELFO',
#   '101 - GIUDICE TAVOLARE DI BRUNICO',
#   '102 - GIUDICE TAVOLARE DI MONGUELFO',
#   '103 - GIUD.TAV. BRESSANONE E CHIUSA',
#   '104 - GIUDICE TAVOLARE DI VIPITENO',
#   '105 - GIUDICE TAVOLARE DI BOLZANO',
#   '106 - GIUDICE TAVOLARE DI CALDARO',
#   '107 - GIUDICE TAVOLARE DI EGNA'],
#  'brindisi  ut dpbr': ['001 - TRIBUNALE DI BRINDISI',
#   '002 - GIUDICE DI PACE DI BRINDISI',
#   '003 - GIUDICE DI PACE DI MESAGNE',
#   '004 - GIUDICE DI PACE DI ORIA',
#   '005 - TRIBUNALE DI FRANCAVILLA F.NA',
#   '006 - TRIBUNALE DI MESAGNE',
#   '007 - GIUDICE DI PACE DI F.LLA F.NA',
#   '008 - GIUDICE DI PACE S. PIETRO V.CO',
#   '009 - XXX',
#   '010 - GDP BRINDISI-EX GDP ORIA',
#   '011 - GDP BRIN. EX GDP S.V.NORMANNI',
#   '012 - GDP BRIN.-EX GDP CEG. MESSAP.'],
#  'busto arsizio  ut dpva': ['001 - PRETURA',
#   '002 - TRIBUNALE',
#   '003 - GIUDICE DI PACE',
#   '004 - CANCELLERIA',
#   '005 - GDP BUSTO ARS-EX GDP GALLARATE'],
#  'cagliari 1  ut dpca': ['001 - TRIBUNALE DI CAGLIARI',
#   '002 - GIUDICE DI PACE - CAGLIARI',
#   "003 - CORTE D'APPELLO CAGLIARI",
#   '004 - GIUDICE DI PACE - PULA',
#   '005 - GIUDICE DI PACE - SINNAI',
#   '006 - GIUDICE DI PACE - MURAVERA',
#   '007 - GIUDICE DI PACE - SENORBI',
#   '008 - GIUDICE DI PACE - DECIMOMANNU',
#   '009 - TRIBUNALE MINORI CAGLIARI',
#   '010 - T.A.R. SARDEGNA',
#   '011 - COMMISSARIO PER GLI USI CIVICI',
#   '012 - PRETURA DI CAGLIARI',
#   '013 - TRIB REG.LE ACQUE PUBBLICHE',
#   '014 - GIUDICE PACE S. NICOLK GERREI',
#   '015 - CCCCCCCCCCCCCCCCCCCCCCCCCCCCCC',
#   "016 - UNEP - CORTE D'APPELLO",
#   '017 - GDP CAGLIARI - EX GDP IGLESIAS',
#   '018 - GDP CAGLIARI - EX GDP CARBONIA',
#   '019 - GDP CAGLIARI - EX GDP SANTADI',
#   '020 - GDP CAGLIARI-EX GDP S.ANTIOCO',
#   '021 - GDP CAGLIARI-EX GDP SERRAMANNA',
#   '022 - GDP CAGLIARI - EX GDP GUSPINI'],
#  'caltagirone  ut dpct': ['001 - TRIBUNALE DI CALTAGIRONE',
#   '002 - TRIBUNALE DI GRAMMICHELE',
#   '003 - GIUDICE DI PACE CALTAGIRONE',
#   '004 - GIUDICE DI PACE GRAMMICHELE',
#   '005 - GIUDICE DI PACE DI RAMACCA',
#   '006 - GIUDICE DI PACE DI MINEO',
#   '007 - GIUDICE DI PACE DI VIZZINI',
#   '008 - PRETURA DI MINEO',
#   '009 - PRETURA DI CALTAGIRONE',
#   '010 - PRETURA MILITELLO V.C.',
#   '011 - UFF. UNEP CALTAGIRONE',
#   '012 - PRETURA DI GRAMMICHELE',
#   '013 - UFF. UNEP GRAMMICHELE'],
#  'caltanissetta  ut dpcl': ['001 - TRIBUNALE',
#   '002 - PRET CL',
#   '003 - CORTE DI APPELLO DI CL',
#   '004 - GIUDICE DI PACE CL',
#   '005 - GIUDICE DI PACE S.CATERINA',
#   '006 - GIUDICE DI PACE SOMMATINO',
#   '007 - TRIBUNALE MINORENNI CALTANIS',
#   '008 - GIUDICE DI PACE DI MUSSOMELI',
#   '009 - GIUDICE DI PACE MUSSOMELI',
#   '010 - GIUDICE DI PACE DI MUSSOMELI'],
#  'camerino  ut dpmc': ['001 - TRIBUNALE DI CAMERINO',
#   '002 - GIUDICE DI PACE DI CAMERINO',
#   '003 - 81002190437',
#   '004 - 81002190437'],
#  'campobasso  ut dpcb': ['001 - TRIBUNALE DI CAMPOBASSO',
#   '002 - PRETURA DI CAMPOBASSO',
#   '003 - CORTE DI APPELLO DI CAMPOBASSO',
#   '004 - GIUD.DI PACE CIVITACAMPOMARANO',
#   '005 - GIUDICE DI PACE DI BOJANO',
#   '006 - GIUDICE DI PACE DI TRIVENTO',
#   '007 - GIUDICE DI PACE DI CAMPOBASSO',
#   '008 - GIUDICE DI PACE DI RICCIA',
#   '009 - TRIBUNALE',
#   '010 - TAR MOLISE'],
#  "canicatti'  ut dpag": ['001 - UFF.GIUD.PACE RAVANUSA',
#   "002 - PRETURA DI CANICATTI'",
#   '003 - PRETURA DI RAVANUSA',
#   '004 - GIUDICE DI PACE DI LICATA',
#   '005 - GIUDICE DI PACE DI PALMA M.RO',
#   '006 - TRIBUNALE AG SEZ.STACC.LICATA',
#   "007 - TRIB.AG. SEZ. DIS.CANICATTI'",
#   '008 - PRETURA DI LICATA',
#   "009 - UFF.GIUD.PACE CANICATTI'"],
#  "cantu'  ut dpco": ["001 - TRIBUNALE DI COMO SEZ. CANTU'",
#   "002 - GIUDICE DI PACE DI CANTU'",
#   "003 - PRETURA DI CANTU'",
#   "004 - UFFICIALI GIUDIZIARI CANTU'"],
#  'caprino veronese  ut dpvr': ['001 - PRETURA DI CAPRINO VERONESE',
#   '002 - GIUDICE DI PACE CAPRINO V.SE'],
#  'carpi  ut dpmo': ['001 - GIUDICE DI PACE DI CARPI',
#   '002 - PRET DI MO SEZ STACC DI CARPI',
#   '003 - TRIB. MODENA SEZIONE CARPI',
#   '004 - TRIB DI MO SEZ DIST DI CARPI',
#   '005 - GIUDICE DI PACE DI MIRANDOLA',
#   '006 - GIUDICE DI PACE DI FINALE E.'],
#  'casale monferrato  ut dpal': ['001 - TRIBUNALE CASALE MONFERRATO',
#   '002 - PRETURA CASALE MONFERRATO',
#   '003 - GIUDICE UNICO CASALE MONFERRAT',
#   '004 - GIUDICE DI PACE CASALE MONF.'],
#  'casalmaggiore  ut dpcr': ['001 - GIUDICE DI PACE CASALMAGGIORE'],
#  'casarano  ut dple': ['001 - TRIBUNALE',
#   '002 - UFFICIO GIUDICE PACE CASARANO',
#   '003 - TRIBUNALE SEZ.DISTAC.CASARANO',
#   '004 - UFFICIO GIUDICE PACE TRICASE',
#   '005 - TRIBUNALE SEZ.DISTAC.TRICASE',
#   '006 - UFFICIO GIUDICE PACE UGENTO',
#   '007 - UFFICIO GIUDICE PACE ALESSANO',
#   '008 - TRIBUNALE DI GALLIPOLI',
#   '009 - GIUDICE DI PACE DI GALLIPOLI'],
#  'caserta  ut dpce': ['001 - TRIBUNALE DI SANTA MARIA C.V.',
#   '002 - PRETURA DI CASERTA',
#   '003 - GIUDICE DI PACE DI CASERTA',
#   '004 - GIUDICE PACE SANTA MARIA C.V',
#   '005 - GIUDICE PACE DI CAPUA',
#   '006 - GIUDICE PACE DI ARIENZO',
#   '007 - GIUDICE DI PACE DI MARCIANISE',
#   '008 - GIUDICE PACE PIGNATARO MAGG.',
#   '009 - GIUDICE DI PACE DI MADDALONI',
#   '010 - GIUDICE PACE DI TEANO',
#   '011 - PRETURA DI S.MARIA C.V.',
#   '012 - PRETURA DI CAPUA',
#   '013 - PRETURA DI ARIENZO',
#   '014 - PRETURA DI MARCIANISE',
#   '015 - PRETURA DI PIGNATARO MAGGIORE',
#   '016 - PRETURA DI MADDALONI',
#   '017 - PRETURA DI TEANO',
#   '018 - TRIB.LE SEZ. DI CASERTA',
#   '019 - UFF.GIUD.TRIB.DI MARCIANISE',
#   '020 - TRIB.LE SEZ. DI MARCIANISE',
#   '021 - GIUDICE PACE PIEDIMONTE MATESE',
#   '022 - GIUD.PACE CAPRIATI A VOLTURNO',
#   '023 - TRIB.LE SEZ. PIEDIMONTE MATESE',
#   '024 - TRIBUNALE S.M.C.V.- C.C.',
#   '025 - TRIBUNALE S.M.C.V.- V.G.'],
#  'casoria  ut dpna1': ['001 - TRIBUNALE CASORIA',
#   '002 - GIUDICE DI PACE CASORIA',
#   '003 - TRIBUNALE AFRAGOLA',
#   '004 - GIUDICE DI PACE AFRAGOLA',
#   '005 - GIUDICE DI PACE DI ACERRA',
#   '006 - GIUDICE PACE POMIGLIANO',
#   '007 - UNEP - TRIB CASORIA',
#   '008 - UNEP TRIB AFRAGOLA'],
#  'cassino  ut dpfr': ['001 - PRETURA DI CASSINO',
#   '002 - GIUDICE DI PACE CASSINO',
#   '003 - GIUDICE DI PACE DI PONTECORVO',
#   '004 - PRETURA PONTECORVO',
#   '005 - TRIBUNALE DI CASSINO',
#   '006 - GDP CASSINO-EX GDP ARCE',
#   '007 - GDP CASSINO-EX GDP ATINA',
#   '008 - GDP CASSINO-EX GDP GAETA',
#   '009 - GDP CASSINO-EX GDP MINTURNO',
#   '010 - GDP CASSINO-EX GDP PONTECORVO',
#   '011 - GDP CASSINO-EX GDP SORA'],
#  'castel di sangro  ut dpaq': ['001 - GIUDICE DI PACE DI C. DI S.',
#   '002 - GIUDICE DI PACE',
#   '003 - GIUDICE DI PACE DI CASTEL DI S',
#   '004 - GIUDICE DI PACE DI CASTEL DI S',
#   '005 - GC096',
#   '006 - GIUDICE DI PACE DI CASTEL DI S'],
#  'castelfranco veneto  ut dptv': ['001 - TRIBUNALE DI TREVISO',
#   '002 - GIUDICE DI PACE',
#   '003 - AC111',
#   '004 - 9BO',
#   '005 - TRIBUNALE CASTELFRANCO VENETO',
#   '006 - TRIB. TV-SEZ.CASTELFRANCO V.TO'],
#  'castellammare di stabia  ut dpna2': ['001 - TRIB. TORRE ANNUNZIATA',
#   '002 - TRIB. SEZ. TORRE DEL GRECO',
#   '003 - TRIB. SEZ. C/MARE DI STABIA',
#   '004 - TRIB. SEZ. DI SORRENTO',
#   '005 - TRIBUNALE SEZ. DI GRAGNANO',
#   '006 - GIUD. PACE DI TORRE ANN.TA',
#   '007 - GIUD. PACE C.MARE STABIA',
#   '008 - GIUDICE PACE DI SORRENTO',
#   '009 - GIUDICE DI PACE POMPEI',
#   '010 - GIUDICE DI PACE GRAGNANO',
#   '011 - GIUD. PACE TORRE DEL GRECO',
#   '012 - TRIBUNALE TORRE ANNUNZIATA',
#   '013 - TRIB.NAPOLI SEZ. CAPRI',
#   '014 - GIUDICE DI PACE CAPRI'],
#  'castelnuovo di garfagnana  ut dplu': ['001 - GIUD. PACE CASTEL. GARFAGNANA',
#   '002 - PRETURA CASTELNUOVO GARF.NA'],
#  'castelvetrano  ut dptp': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE CASTELVETRANO',
#   '003 - PRET.CIR.MARSALA SEZ.C.VETRANO',
#   '004 - GIUDICE DI PACE PARTANNA',
#   '005 - GIUDICE DI PACE SALEMI',
#   '006 - PRET.SEZ.STACC.PARTANNA',
#   '007 - PRET.SEZ.STACC.SALEMI',
#   '008 - TRIB. SEZ. STACCATA C.VETRANO',
#   '009 - TRIB. SEZ. STACCATA PARTANNA',
#   '010 - UFFICIALE GIUDIZIARIO',
#   '011 - TRIB. DI CASTELVETRANO'],
#  'castiglione delle stiviere  ut dpmn': ['001 - PRETURA CASTIGLIONE D.S.',
#   '002 - GIUDICE PACE CASTIGLIONE D.S.',
#   '003 - GIUDICE PACE ASOLA',
#   '004 - TRIBUNALE DI MN S.S.CASTIGLION',
#   '005 - TRIBUNALE MN S.ST.CASTIGLIONE',
#   '006 - PRETURA DI CASTIGLIONE STIVIER',
#   '007 - GIUDICE DI PACE CASTIGLIONE ST',
#   '008 - GIUDICE DI PACE ASOLA',
#   '009 - TRIBUNALE MN S.S.CASTIGLIONE',
#   '010 - U.N.E.P. CASTIGLIONE STIVIERE',
#   '011 - TRIBUNALE DI MN S.S. CASTIGLIO'],
#  'castrovillari  ut dpcs': ['001 - TRIBUNALE',
#   '002 - PRETURA',
#   '003 - GIUDICE PACE CASTROVILLARI',
#   '004 - GIUDICE DI PACE CASSANO J.',
#   '005 - GIUDICE PACE SPEZZANO ALBANESE',
#   '006 - GIUDICE DI PACE DI LUNGRO',
#   '007 - GIUDICE DI PACE DI MORMANNO',
#   '008 - PRETURA DI CASSANO JONIO',
#   '009 - PRETURA DI TREBISACCE',
#   '010 - GIUDICE DI PACE DI ORIOLO',
#   '011 - GIUDICE DI PACE DI TREBISACCE',
#   '012 - ISTITUTO VENDITE GIUDIZIARIE',
#   '013 - UNEP CASTROVILLARI',
#   '014 - GIUDICE DI PACE TREBISACCE',
#   '015 - GIUDICE DI PACE DI TREBISACCE',
#   '016 - GIUDICE DI PACE TREBISACCE',
#   '017 - GIUDICE DI PACE TREBISACCE'],
#  'catania  ut dpct': ['001 - TRIBUNALE DI CATANIA',
#   '002 - TRIB.CT SEZ.DISTACC.MASCALUCIA',
#   '003 - CORTE DI APPELLO DI CATANIA',
#   '004 - UFF.GIUD.DI PACE DI CATANIA',
#   '005 - UFF.GIUD.DI PACE DI MASCALUCIA',
#   '006 - TRIB.PER I MINORENNI CATANIA',
#   '007 - TRIB.CT SEZ.DISTACC. DI ADRANO',
#   "008 - TRIB.CT SEZ. DISTACC. PATERNO'",
#   '009 - TRIB.CT SEZ. DISTACC.BRONTE',
#   '010 - UFF.GIUD.PACE DI ADRANO',
#   "011 - UFF.GIUD.DI PACE PATERNO'",
#   '012 - TRIBUNALE AMM.VO REGIONALE CT',
#   '013 - UFF.GIUDICE DI PACE BELPASSO',
#   '014 - TRIB. CT SEZ. DIST. BELPASSO',
#   '015 - UFF. GIUD. PACE MILITELLO V.C.',
#   '016 - GIUDICE DI PACE DI BRONTE',
#   '017 - TRIBUNALE CT - SEZ. STRALCIO',
#   '018 - UFF. GIUD. PACE DI BIANCAVILLA',
#   '019 - COMUNE DI ZAFFERANA ETNEA',
#   '020 - COMUNE DI SAN GIOVANNI LA PUNT'],
#  'catanzaro  ut dpcz': ['001 - PRETURA CATANZARO',
#   '002 - CORTE APPELLO CATANZARO',
#   '003 - GIUDICE DI PACE',
#   '004 - CORTE APPELLO',
#   '005 - TRIBUNALE DI CATANZARO',
#   '006 - TRIBUNALE DI CZ SEZ.STACCATA',
#   '007 - GIUDICE PACE SEZ.CHIARAVALLE',
#   '008 - TRIBUNALE',
#   '009 - TRIBUNALE',
#   '010 - 5 TRIBUNALE',
#   '011 - GIUDICE DI PACE DI SQUILLACE',
#   '012 - GIUDICE DI PACE DI BADOLATO',
#   '013 - GIUDICE DI PACE DI BADOLATO',
#   '014 - GIUDICE DI PACE DI DAVOLI',
#   '015 - GIUDICE PACE CROPANI',
#   '016 - GIUDICE PACE TIRIOLO',
#   '017 - GIUDICE PACE TAVERNA',
#   '018 - T.A.R.',
#   '019 - GIUDICE DI PACE DI BORGIA',
#   '020 - CORTE DI APPELLO CZ',
#   '021 - 5TRIBUNALE',
#   '022 - TRIBUNALE CHIARAVALLE CENTRALE',
#   '023 - TRIBUNALE PER I MINORENNI'],
#  'cavalese  ut dptn': ['001 - GIUDICE DI PACE DI CAVALESE',
#   '002 - PRETURA DI CAVALESE',
#   '003 - TRIBUNALE DI CAVALESE',
#   '004 - TRIBUNALE'],
#  "cefalu'  ut dppa": ["001 - PRETURA DI CEFALU'",
#   "002 - GIUDICE DI PACE DI CEFALU'",
#   "003 - TRIBUNALE SEZ.STAC.CEFALU'",
#   '004 - UFF.NOTIF.ESECUZ.PROT.CEFALU',
#   '005 - GIUDICE DI PACE'],
#  'cento  ut dpfe': ['001 - GIUDICE DI PACE DI CENTO'],
#  'cerignola  ut dpfg': ['001 - GIUDICE DI PACE DI ORTA NOVA',
#   '002 - GIUDICE DI PACE DI TRINITAPOLI',
#   '003 - PRETURA DI CERIGNOLA',
#   '004 - PRETURA DI TRINITAPOLI',
#   '005 - GIUDICE DI PACE DI CERIGNOLA',
#   '006 - UFF. GIUD. TRIB. CERIGNOLA',
#   '007 - UFF.GIUD. TRIB. TRINITAPOLI',
#   '008 - TRIB. FOGGIA - SEZ.STAC.CERIGN',
#   '009 - TRIBUNALE DI TRINITAPOLI',
#   '010 - TRIBUNALE DI CERIGNOLA',
#   '011 - UFF.GIUD.TRIB.TRINITAPOLI',
#   '012 - UFF.GIUD.TRIB.CERIGNOLA',
#   '013 - TRIB.FOGGIA-SEZ.ST.TRINITAPOLI',
#   '014 - TRIBUNALE DI CERIGNOLA',
#   '015 - TRIBUNALE DI CERIGNOLA'],
#  'cervignano del friuli  ut dpud': ['001 - TRIBUNALE DI PALMANOVA',
#   '002 - GIUDICE DI PACE DI PALMANOVA',
#   '003 - GIUDICE DI PACE DI CERVIGNANO',
#   '004 - GIUDICE DI PACE DI LATISANA',
#   '005 - TRIB.UD.SEZ.STAC.LATISANA'],
#  'cesena  ut dpfc': ['001 - TRIBUNALE DI CESENA',
#   '002 - GIUDICE DI PACE DI CESENA',
#   '003 - GIUDICE DI PACE DI BAGNO DI R.',
#   '004 - UFFICIALI GIUDIZIARI DI CESENA'],
#  'chatillon  ut drao': ['001 - GIUDICE DI PACE DI DONNAS',
#   '002 - VD338',
#   '003 - 1-GIUDICE DI PACE DI DONNAS',
#   '004 - 1-GIUDICE DI PACE DI DONNAS'],
#  'chiari  ut dpbs': ['001 - GIUDICE DI PACE DI CHIARI',
#   '002 - GIUDICE DI PACE ROVATO'],
#  'chiavari  ut dpge': ['001 - TRIBUNALE',
#   '002 - ISP.COMP.TASSE E IMPOSTE IND.',
#   '003 - PRETURA DI CHIAVARI',
#   '004 - PRETURA SESTRI LEVANTE',
#   '005 - GIUDICE DI PACE DI CHIAVARI',
#   '006 - GIUDICE DI PACE SESTRI LEV.',
#   '007 - GIUDICE DI PACE RAPALLO',
#   '008 - LOCAMARE SESTRI LEVANTE',
#   '009 - GIUDICE DI PACE RECCO',
#   '010 - LOCAMARE CHIAVARI',
#   '011 - UNEP TRIBUNALE DI CHIAVARI'],
#  'chieri  ut dpto1': ['001 - GIUDICE DI PACE DI CHIERI'],
#  'chieti  ut dpch': ['001 - TRIBUNALE CHIETI',
#   '002 - GIUDICE PACE CHIETI',
#   '003 - GIUDICE PACE FRANCAVILLA',
#   '004 - GIUDICE PACE GUARDIAGRELE',
#   '005 - GDP CHIETI -EX GDP FRANCAVILLA',
#   '006 - GDP CHIETI EX GDP GUARDIAGRELE',
#   '007 - GDP CHIETI - EX GDP ORSOGNA',
#   '008 - GDP CHIETI EX GDP ORTONA',
#   '009 - GDP CHIETI EX GDP L.DEI PEL.'],
#  'chioggia  ut dpve': ['001 - TRIB.ORD. VE SEZ.CHIOGGIA',
#   '002 - GIUDICE DI PACE CAVARZERE',
#   '003 - GIUDICE PACE CHIOGGIA',
#   '004 - TRIBUNALE ORDINARIO VE'],
#  'chivasso  ut dpto2': ['001 - GIUDICE DI PACE CHIVASSO',
#   '002 - PRETURA DI CHIVASSO',
#   '003 - TRIBUNALE SEZ. DI CHIVASSO',
#   '004 - C.I.S.A. 07306200010'],
#  "cirie'  ut dpto2": ["001 - TRIBUNALE DI CIRIE'",
#   '002 - GIUDICE DI PACE DI CIRIE',
#   '003 - GIUDICE PACE DI LANZO T.SE'],
#  "citta' di castello  ut dppg": ['001 - TRIB. PG SEZ. C.DI CASTELLO',
#   '002 - GIUDICE DI PACE C.DI CASTELLO'],
#  'cittadella  ut dppd': ['001 - PRETURA DI CITTADELLA',
#   '002 - GIUDICE DI PACE',
#   '003 - TRIB.PADOVA - SEZ. CITTADELLA',
#   '004 - TRIBUNALE - UFFICIO NEP'],
#  'civitavecchia  ut dprm2': ['001 - TRIBUNALE DI CIVITAVECCHIA',
#   '002 - GIUDICE DI PACE DI BRACCIANO',
#   '003 - GIUDICE DI PACE DI FIUMICINO',
#   '004 - GIUD. DI PACE DI CIVITAVECCHIA'],
#  'civitavecchia - ante 01.02.2015 ut dprm1': ['001 - TRIBUNALE DI CIVITAVECCHIA',
#   '002 - PRETURA DI CIVITAVECCHIA',
#   '003 - GIUDICE DI PACE CIVITAVECCHIA',
#   '004 - TRIBUNALE DI BRACCIANO',
#   '005 - TRIB. C.VECCHIA SEZ. BRACCIANO',
#   '006 - TRIB. ROMA - SEZ. BRACCIANO',
#   '007 - TRIB. ROMA - SEZ. OSTIA',
#   '008 - PRETURA ROMA - SEZ. BRACCIANO',
#   '009 - GIUDICE DI PACE - BRACCIANO',
#   '010 - GIUDICE DI PACE FIUMICINO',
#   '011 - TRIBUNALE DI CIVITAVECCHIA'],
#  'cles  ut dptn': ['001 - GIUDICE DI PACE DI FONDO',
#   '002 - GIUDICE DI PACE DI CLES',
#   '003 - GIUDICE DI PACE DI MALH',
#   '004 - TRIBUNALE DI CLES'],
#  'clusone  ut dpbg': ['001 - PRETURA DI CLUSONE',
#   '002 - GIUDICE DI PACE DI CLUSONE',
#   '003 - GIUDICE DI PACE DI LOVERE',
#   '004 - TRIBUNALE DI CLUSONE',
#   '005 - TRIBUNALE'],
#  'codogno  ut dplo': ['001 - GIUDICE DI PACE DI CODOGNO',
#   '002 - GIUDICE DI PACE DI CODOGNO'],
#  'comacchio  ut dpfe': ['001 - GIUDICE DI PACE DI COMACCHIO',
#   '002 - GIUDICE DI PACE DI CODIGORO',
#   '003 - PRETURA CIRC. FE-SEZ.COMACCHIO',
#   '004 - GNODVD69L02D548Q',
#   '005 - UFFICIO LOC MARITTIMO DI GORO',
#   '006 - GIUDICE DI PACE DI COMACCHIO',
#   '007 - GIUDICE DI PACE DI COMACCHIO'],
#  'como  ut dpco': ['001 - TRIBUNALE DI COMO',
#   '002 - GIUDICE DI PACE DI COMO',
#   '003 - TRIBUNALE DI MENAGGIO',
#   '004 - GIUDICE DI PACE DI MENAGGIO',
#   "005 - GDP COMO-EX GDP CANTU'",
#   '006 - GDP COMO-EX GDP ERBA'],
#  'conegliano  ut dptv': ['001 - GIUDICE DI PACE DI CONEGLIANO',
#   '002 - TRIBUNALE - SEZIONE CONEGLIANO',
#   '003 - GIUDICE PACE VITTORIO VENETO',
#   '004 - PRETURA VITTORIO VENETO'],
#  'conegliano - vittorio veneto  ut dptv': ['001 - GIUDICE DI PACE DI CONEGLIANO',
#   '002 - TRIBUNALE - SEZIONE CONEGLIANO',
#   '003 - GIUDICE PACE VITTORIO VENETO',
#   '004 - PRETURA VITTORIO VENETO'],
#  'corteolona  ut dppv': ['001 - GIUDICE DI PACE DI CORTEOLONA',
#   '002 - GIUDICE DI PACE DI CORTEOLONA'],
#  'cosenza  ut dpcs': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE',
#   '003 - TRIBUNALE DI SAN MARCO ARG/NO',
#   '004 - GIUD.PACE SAN GIOV.IN FIORE',
#   '005 - GIUD.PACE ROGLIANO',
#   '006 - GIUD.PACE MONTALTO',
#   '007 - GIUD.PACE SAN MARCO ARG/NO',
#   '008 - GIUD.PACE SPEZZANO SILA',
#   '009 - GIUDICE DI PACE DI COSENZA',
#   '010 - TRIBUNALE DI ACRI',
#   '011 - UFFICIO DEL GIUDICE DI PACE DI',
#   '012 - GIUDICE DI PACE ACRI'],
#  'crema  ut dpcr': ['001 - TRIBUNALE DI CREMA',
#   '002 - GIUDICE DI PACE DI CREMA'],
#  'cremona  ut dpcr': ['001 - PRETURA',
#   '002 - PRETURA DI CREMONA',
#   '003 - TRIBUNALE DI CREMONA',
#   '004 - GIUDICE DI PACE DI CREMONA',
#   '005 - GIUDICE DI PACE DI SORESINA',
#   '006 - GDP CREMONA-EX GDP CASALMAGG.',
#   '007 - GDP CREMONA-EX GDP SORESINA'],
#  'crotone  ut dpkr': ['001 - TRIBUNALE DI CROTONE',
#   '002 - GIUDICE DI PACE DI CROTONE',
#   '003 - TRIB. CROTONE-SEZ.STRONGOLI',
#   '004 - GIUDICE PACE STRONGOLI',
#   '005 - GIUDICE PACE PETILIA POLICASTR',
#   '006 - GIUDICE PACE SANTA SEVERINA',
#   "007 - GIUDICE PACE CIRO'",
#   '008 - GIUDICE PACE SAVELLI',
#   '009 - CORTE DI CASSAZIONE',
#   "010 - CORTE D'APPELLO CATANZARO"],
#  'cuneo  ut dpcn': ['001 - TRIBUNALE CUNEO',
#   '002 - PRETURA DI CUNEO',
#   '003 - GIUDICE DI PACE DI CUNEO',
#   '004 - GIUDICE DI PACE DI DRONERO',
#   '005 - GIUD. PACE BORGO S. DALMAZZO',
#   '006 - G.D.P. CUNEO - EX GDP FOSSANO',
#   '007 - GIUDICE DI PACE DI MONDOVI',
#   '008 - GIUDICE DI PACE DI SALUZZO'],
#  "cuorgne'  ut dpto2": ["001 - PRETURA DI CUORGNE'",
#   "002 - GIUDICE DI PACE DI CUORGNE'",
#   "003 - PRETURA DI CUORGNE'",
#   '004 - GIUDICE DI PACE',
#   "005 - PRETURA DI CUORGNE'",
#   '006 - PRETURA RIVAROLO CANAVESE',
#   '007 - GIUD.DI PACE RIVAROLO CANAVESE',
#   '008 - GIUD.PACE DI RIVAROLO CANAVESE'],
#  'desio  ut dpmb': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE',
#   '003 - RETE FERROVIARIA ITALIANA'],
#  'domodossola  ut dpvb': ['001 - TRIBUNALE DOMODOSSOLA',
#   '002 - GIUDICE DI PACE DI DOMODOSSOLA'],
#  'eboli  ut dpsa': ['001 - CANCELLERIA PRETURA EBOLI',
#   '002 - CANCELLERIA TRIBUNALE EBOLI',
#   '003 - CANCELLERIA GIUDICE PACE EBOLI',
#   '004 - CANC.GIUDICE PACE ROCCADASPIDE',
#   '005 - CANC.GIUDICE PACE LAVIANO',
#   '006 - CANC.GIUDICE PACE CAPACCIO',
#   '007 - PRETURA EBOLI',
#   '008 - TRIBUNALE EBOLI',
#   '009 - GIUDICE PACE EBOLI',
#   '010 - GIUDICE PACE ROCCADASPIDE',
#   '011 - GIUDICE PACE LAVIANO',
#   '012 - GIUDICE DI PACE DI BUCCINO',
#   "013 - GIUDICE PACE SANT'ANGELO A F",
#   '014 - GRNGRS69R29H703O',
#   '015 - GIUDICE DI PACE EBOLI',
#   '016 - TRIBUNALE DI EBOLI'],
#  'empoli  ut dpfi': ['001 - TRIB. C. E P. DI FI SEZ EMPOLI',
#   '002 - GIUDICE DI PACE DI EMPOLI',
#   '003 - GIUDICE DI PACE DI CASTEL.NO',
#   '004 - GIUDICE DI PACE',
#   '005 - GIUDICE DI PACE'],
#  'enna  ut dpen': ['001 - TRIBUNALE DI ENNA',
#   '002 - GIUDICE DI PACE DI ENNA',
#   '003 - GDP B.FRANCA FINO A MARZO 2017',
#   '004 - GIUDICE DI PACE DI P.ARMERINA',
#   '005 - GIUDICE DI PACE DI VILLAROSA',
#   '006 - GIUDICE DI PACE DI REGALBUTO',
#   '007 - GIUDICE DI PACE DI LEONFORTE',
#   '008 - TRIBUNALE DI NICOSIA',
#   '009 - GIUDICE DI PACE DI NICOSIA',
#   '010 - GIUDICE DI PACE DI TROINA',
#   '011 - GIUDICE DI PACE DI CENTURIPE',
#   '012 - GIUDICE DI PACE DI AGIRA',
#   '013 - GIUDICE DI PACE DI AIDONE',
#   '014 - GIUDICE DI PACE DI VALGUARNERA',
#   '015 - UFFICIALE GIUDIZ.TRIB.ENNA',
#   '016 - GDP BARRAFRANCA DAL 1/4/ 2017'],
#  'erba  ut dpco': ['001 - PRETURA DI ERBA',
#   '002 - GIUDICE DI PACE DI ERBA',
#   '003 - TRIBUNALE DI ERBA'],
#  'este  ut dppd': ['001 - PRETURA DI ESTE',
#   '002 - PRETURA DI MONSELICE',
#   '003 - PRETURA DI MONTAGNANA',
#   '004 - GIUDICE DI PACE DI ESTE',
#   '005 - GIUDICE DI PACE DI MONSELICE',
#   '006 - GIUDICE DI PACE DI MONTAGNANA',
#   '007 - TRIBUNALE DI PADOVA SE.DI ESTE',
#   '008 - BD442',
#   '009 - TRIB.DI PADOVA SEZ.DI ESTE'],
#  'fabriano  ut dpan': ['001 - TRIBUNALE DI FABRIANO',
#   '002 - BCCGNN53H64I608G',
#   '003 - MLVRFL52L29F839O',
#   '004 - TTNCSR61D11H501Y',
#   '005 - STRLSN54H02B474K',
#   '006 - GIUDICE DI PACE',
#   '007 - CANCELLIERE',
#   '008 - CANCELLIERE',
#   '009 - GIUDICE DI PACE DI ANCONA'],
#  'faenza  ut dpra': ['001 - CESSATO - PRETURA FAENZA',
#   '002 - GIUDICE DI PACE DI FAENZA',
#   '003 - TRIBUNALE DI RAVENNA SS FAENZA',
#   '004 - CESSATO- TRIB.RAVENNA S.FAENZA'],
#  'fano  ut dppu': ['001 - TRIBUNALE PESARO SEZ.ST. FANO',
#   '002 - GIUDICE DI PACE DI FANO',
#   '003 - GIUDICE DI PACE DI PERGOLA',
#   '004 - COMUNITA MONTANA CATRIA E CESA',
#   '005 - CCCPLA49C09G537K'],
#  'feltre  ut dpbl': ['001 - GIUDICE DI PACE DI FELTRE',
#   '002 - PRETURA FELTRE',
#   '003 - 7 REGIMENTO ALPINI'],
#  'fermo  ut dpfm': ['001 - TRIBUNALE DI FERMO',
#   '002 - TRIB. FERMO SEDE STACC. S.E.M.',
#   '003 - GIUDICE DI PACE DI FERMO',
#   '004 - GIUDICE DI PACE DI S.E.M.',
#   '005 - GIUDICE DI PACE DI M.GIORGIO',
#   '006 - PRETURA DI FERMO',
#   '007 - PRETURA S.ELPIDIO A MARE',
#   '008 - PRETURA MONTE GIORGIO',
#   '009 - PRETURA DI RIPATRANSONE',
#   '010 - GIUDICE DI PACE DI AMANDOLA',
#   '011 - GDP FERMO -EX GDP RIPATRANSONE'],
#  'ferrara  ut dpfe': ['001 - TRIBUNALE DI FERRARA',
#   '002 - GIUDICE DI PACE DI FERRARA',
#   '003 - GIUDICE DI PACE DI COPPARO',
#   '004 - GIUDICE DI PACE PORTOMAGGIORE',
#   '005 - GIUDICE DI PACE DI ARGENTA',
#   '006 - GDP FERRARA -EX GDP CENTO',
#   '007 - GDP FERRARA - EX GDP CODIGORO',
#   '008 - GDP FERRARA - EX GDP COMACCHIO'],
#  'fidenza  ut dppr': ['001 - TRIB. PARMA-SEZ.STACC.FIDEN',
#   '002 - GIUDICE DI PACE DI FIDENZA',
#   '003 - SPSMSM74D22H703L',
#   '004 - UFFICIALE GIUDIZIARIO FIDENZA'],
#  "fiorenzuola d'arda  ut dppc": ["001 - PRETURA FIORENZUOLA D'ARDA",
#   '002 - GIUDICE DI PACE FIORENZUOLA'],
#  'firenze  ut dpfi': ['001 - CORTE DI APPELLO',
#   '002 - GIUDICE UNICO-EX-PRET.VARI',
#   '003 - GIUDICE UNICO EX-PRET.DECR.ING',
#   '004 - GIUDICE UNICO EX-TRIB SENTENZE',
#   '005 - GIUDICE UNICO EX-TRIB.VARI',
#   '006 - GIUDICE DI PACE FIRENZE',
#   '007 - GIUDICE UNICO PONTASSIEVE',
#   '008 - GIUDICE DI PACE PONTASSIEVE',
#   '009 - TRIBUNALE DEI MINORENNI',
#   '010 - GIUDICE UNICO BORGO S.L.',
#   '011 - TRIBUNALE ACQUE PUBBLICHE',
#   '012 - TRIBUNALE SEZ.FALLIMENTARE',
#   '013 - T.A.R. TOSCANA',
#   '014 - TRIB. FIRENZE SEZ. EMPOLI',
#   '015 - G.D.P. FIRENZE EX EMPOLI',
#   '016 - G.D.P. FI EX CASTELFIORENTINO',
#   '017 - G.D.P. FI EX BORGO SAN LORENZO',
#   '018 - TRIBUNALE DI SORVEGLIANZA',
#   '019 - GIUDICE DI PACE DI EMPOLI'],
#  'firenze 2  ut dpfi': ['001 - CORTE DI APPELLO',
#   '002 - GIUDICE UNICO-EX-PRET.VARI',
#   '003 - GIUDICE UNICO EX-PRET.DECR.ING',
#   '004 - GIUDICE UNICO EX-TRIB SENTENZE',
#   '005 - GIUDICE UNICO EX-TRIB.VARI',
#   '006 - GIUDICE DI PACE FIRENZE',
#   '007 - GIUDICE UNICO PONTASSIEVE',
#   '008 - GIUDICE DI PACE PONTASSIEVE',
#   '009 - TRIBUNALE DEI MINORENNI',
#   '010 - GIUDICE UNICO BORGO S.L.',
#   '011 - TRIBUNALE ACQUE PUBBLICHE',
#   '012 - TRIBUNALE SEZ.FALLIMENTARE',
#   '013 - T.A.R. TOSCANA',
#   '014 - TRIB. FIRENZE SEZ. EMPOLI',
#   '015 - G.D.P. FIRENZE EX EMPOLI',
#   '016 - G.D.P. FI EX CASTELFIORENTINO',
#   '017 - G.D.P. FI EX BORGO SAN LORENZO',
#   '018 - TRIBUNALE DI SORVEGLIANZA'],
#  'foggia  ut dpfg': ['001 - GDP PROVINCIA DI FOGGIA',
#   '002 - TRIBUNALE DI FOGGIA - SICID',
#   '003 - GIUDICE DI PACE DI FOGGIA',
#   '004 - TRIB. FOGGIA-EX SEZ MANFREDON.',
#   '005 - TRIB. FOGGIA-CARTACEO',
#   '006 - TRIB. FOGGIA-EX SEZ S.SEVERO',
#   '007 - TRIB.FOGGIA-EX SEZ TRINITAPOLI',
#   '008 - TRIB FOGGIA- EX SEZ CERIGNOLA',
#   '009 - GDP FOGGIA - EX GDP BOVINO',
#   '010 - GDP FOGGIA-EX GDP ORTA NOVA',
#   '011 - GDP FOGGIA - EX GDP TROIA',
#   '012 - TRIB. FOGGIA - SEZ PENALE',
#   '013 - TRIB FG- CONT.CIV E VOL.GIUR.',
#   '014 - TRIB FG - ESECUZ.MOB. E IMMOB.',
#   '015 - TRIB.FOGGIA - PROCED.FALLIMENT',
#   '016 - TRIB. FOGGIA - UNEP'],
#  'foligno  ut dppg': ['001 - TRIBUNALE PG SEZ. FOLIGNO',
#   '002 - GIUDICE DI PACE DI FOLIGNO',
#   '003 - GIUDICE DI PACE DI MONTEFALCO',
#   '004 - UFFICIALE GIUD. TRIB. FOLIGNO',
#   '005 - TRIB.PG SEZ.ASSISI DAL 1/3/12',
#   '006 - GIUDICE PACE ASSISI DAL 1/3/12'],
#  "forli'  ut dpfc": ['001 - TRIBUNALE',
#   '002 - PRETURA',
#   '003 - GIUDICE DI PACE',
#   '004 - TRIBUNALE DI FORLI',
#   '005 - PRETURA DI FORLI',
#   '006 - GIUDICE DI PACE DI FORLI',
#   "007 - GDP FORLI'-EX GDP BAGNO DI RO.",
#   "008 - GDP FORLI'- EX GDP CESENA"],
#  'formia  ut dplt': ['001 - PRETURA DI GAETA',
#   '002 - PRETURA DI FONDI',
#   '003 - PRETURA DI MINTURNO',
#   '004 - GIUDICE PACE GAETA',
#   '005 - GIUDICE PACE FONDI',
#   '006 - GIUDICE PACE MINTURNO',
#   '007 - TRIBUNALE DI LATINA SEZ GAETA',
#   '008 - PRETURA GAETA',
#   '009 - TRIB. LT SEZ. GAETA'],
#  'fossano  ut dpcn': ['001 - GIUDICE DI PACE DI FOSSANO',
#   '002 - SEZ.DIST.FOSSANO PRETURA DI CN'],
#  'frascati  ut dprm3': ['001 - TRIB VELLETRI SEZ ST FRASCATI',
#   '002 - GIUDICE PACE FRASCATI',
#   '003 - TRIBUN. ORDINARIO DI VELLETRI',
#   '004 - SEZ.STACC. FRASCATI',
#   '005 - GIUDICE DI PACE FRASCATI',
#   '006 - TRIBUNALE CIVILE ROMA',
#   '007 - TRIBUNALE CIVILE DI ROMA'],
#  'frosinone  ut dpfr': ['001 - TRIBUNALE DI FROSINONE',
#   '002 - GIUDICE DI PACE DI ANAGNI',
#   '003 - GIUDICE DI PACE DI ALATRI',
#   '004 - GIUDICE DI PACE DI FERENTINO',
#   '005 - GIUDICE DI PACE DI FROSINONE',
#   '006 - GIUDICE DI PACE DI CECCANO',
#   '007 - PRETURA DI ANAGNI',
#   '008 - PRETURA DI ALATRI',
#   '009 - PRETURA DI FROSINONE',
#   '010 - PRETURA DI CECCANO',
#   '011 - TRIBUNALE DI ANAGNI',
#   '012 - TRIBUNALE DI ALATRI'],
#  'gallarate  ut dpva': ['001 - TRIBUNALE',
#   '002 - TRIBUNALE DI BUSTO ARSIZIO',
#   '003 - GIUDICE DI PACE',
#   '004 - GIUDICE DI PACE DI GALLARATE',
#   '005 - TRIB. BUSTO A. SEZ. GALLARATE'],
#  'gallipoli  ut dple': ['001 - TRIBUNALE DI GALLIPOLI',
#   '002 - TRIBUNALE DI NARDO',
#   '003 - GIUDICE DI PACE DI NARDO',
#   '004 - GIUDICE DI PACE DI GALLIPOLI',
#   '005 - COMUNE DI NARDO',
#   '006 - 82001370756'],
#  'gardone val trompia  ut dpbs': ['001 - GIUDICE DI PACE GARDONE V.T.'],
#  'gavirate  ut dpva': ['001 - GIUDICE DI PACE DI GAVIRATE',
#   '002 - TRIBUNALE VARESE-SEZ. GAVIRATE',
#   '003 - PRETURA VARESE SEZIONE LUINO',
#   '004 - GIUDICE DI PACE DI LUINO',
#   '005 - TRIB. VARESE SEZ.STAC. LUINO'],
#  'gela  ut dpcl': ['001 - TRIBUNALE DI GELA',
#   '002 - ENTE SOPPRESSO',
#   '003 - PRETURA',
#   '004 - GIUDICE DI PACE DI NISCEMI',
#   '005 - GIUDICE DI PACE DI GELA',
#   '006 - GIUDICE DI PACE DI RIESI',
#   '007 - GIUDICE DI PACE DI MAZZARINO',
#   '008 - GIUDICE DI PACE DI GELA',
#   '009 - GIUDICE DI PACE DI NISCEMI',
#   '010 - GIUDICE DI PACE DI RIESI',
#   '011 - GIUDICE DI PACE DI NISCEMI',
#   '012 - TRIBUNALE GELA',
#   '013 - GIUDICE DI PACE DI GELA'],
#  'gemona del friuli  ut dpud': ['001 - GIUDICE DI PACE'],
#  'genova 1  ut dpge': ['001 - TRIBUNALE DI GENOVA',
#   '002 - PRETURA DI GENOVA',
#   '003 - GIUDICE PACE GENOVA',
#   '004 - GIUDICE PACE SESTRI PONENTE',
#   '005 - GIUDICE PACE VOLTRI',
#   '006 - GIUDICE PACE PONTEDECIMO',
#   '007 - CORTE DI APPELLO',
#   '008 - TRIBUNALE SEZ.MINORI',
#   '009 - UFFICIALI GIUDIZIARI',
#   '010 - 03480370109',
#   '011 - 03497490106',
#   '012 - 03495500104',
#   '013 - 01425900204',
#   '014 - 03787650104',
#   '015 - T.A.R. LIGURIA',
#   '016 - TRIB.GENOVA-EX TRIB.CHIAVARI',
#   '017 - TRIBUNALE DI SORV. GENOVA'],
#  'giarre  ut dpct': ['001 - PRETURA DI GIARRE',
#   '002 - GIUDICE DI PACE DI GIARRE',
#   '003 - GIUDICE DI PACE LINGUAGLOSSA',
#   '004 - GIUDICE DI PACE RANDAZZO',
#   '005 - GIUDICE DI PACE DI GIARRE',
#   '006 - TRIBUNALE DI GIARRE'],
#  'gioia del colle  ut dpba': ['001 - PRET. PUTIGNANO',
#   '002 - PRET. NOCI',
#   '003 - TRIBUNALE ACQUAVIVA DELLE FONT',
#   '004 - GIUDICE DI PACE ACQUAVIVA',
#   '005 - TRIBUNALE ALTAMURA',
#   '006 - GIUDICE DI PACE ALTAMURA',
#   '007 - GIUDICE DI PACE DI GRAVINA',
#   '008 - TRIBUNALE PUTIGNANO',
#   '009 - GIUDICE DI PACE DI PUTIGNANO',
#   '010 - GIUDICE DI PACE DI NOCI',
#   '011 - GIUDICE DI PACE DI GIOIA DEL C',
#   '012 - PRET.PUTIGNANO'],
#  'giulianova  ut dpte': ['001 - PRETURA DI GIULIANOVA',
#   '002 - PRETURA DI NERETO',
#   '003 - GIUDICE DI PACE NERETO',
#   '004 - GIUDICE DI PACE GIULIANOVA',
#   '005 - TRIB. DI TE SEZ GIULIANOVA'],
#  'gorgonzola  ut dpmi2': ["001 - GIUDICE PACE CASSANO D'ADDA",
#   "002 - TRIBUNALE - S.S.CASSANO D'ADDA",
#   "003 - UFFICIALI GIUD. CASSANO D'ADDA"],
#  'gorizia  ut dpgo': ['001 - GIUDICE DI PACE DI GORIZIA',
#   '002 - TRIBUNALE DI GORIZIA',
#   '003 - GIUDICE DI PACE DI GRADISCA',
#   '004 - GIUDICE DI PACE DI GRADISCA',
#   '005 - GDP GORIZIA -EX GDP MONFALCONE',
#   '101 - GIUDICE TAVOLARE DI GORIZIA',
#   '102 - GIUD. TAVOLARE GRADISCA ISONZO'],
#  'grosseto  ut dpgr': ['001 - TRIBUNALE DI GROSSETO',
#   '002 - GIUDICE DI PACE DI GROSSETO',
#   '003 - GIUDICE DI PACE DI ARCIDOSSO',
#   '004 - GIUDICE DI PACE DI M.MARITTIMA',
#   '005 - TRIB. GROSSETO SEZ. ORBETELLO',
#   '006 - GDP GROSSETO-EX GDP ORBETELLO',
#   '007 - GDP GROSSETO-EX GDP PITIGLIANO'],
#  'gualdo tadino  ut dppg': ['001 - GIUDICE DI PACE GUALDO TADINO',
#   '002 - GIUDICE DI PACE DI GUBBIO',
#   '003 - TRIBUNALE PERUGIA SEZ.GUBBIO'],
#  'guastalla  ut dpre': ['001 - GIUDICE DI PACE DI GUASTALLA',
#   '002 - CANCELLERIA PRETURA GUASTALLA',
#   '003 - TRIBUNALE RE SEZ. DI GUASTALLA'],
#  'iglesias  ut dpca': ['001 - TRIBUNALE DI IGLESIAS',
#   '002 - TRIBUNALE DI CARBONIA',
#   '003 - GIUDICE DI PACE IGLESIAS',
#   '004 - GIUDICE DI PACE S. ANTIOCO',
#   '005 - GIUDICE DI PACE CARBONIA',
#   '006 - GIUDICE DI PACE SANTADI'],
#  'imola  ut dpbo': ['001 - UFFICIO GIUDICE DI PACE',
#   '002 - TRIB. VOL. GIURISD. INF.',
#   '003 - UFFICIALE GIUDIZ. IMOLA',
#   '004 - TRIB.BOLOGNA SEZ.IMOLA',
#   '005 - GIUDICE DI PACE',
#   '006 - TRIB.IMOLA-REP.INFORMATIZZ.',
#   '007 - GDP IMOLA - EX GDP BUDRIO'],
#  'imperia  ut dpim': ['001 - GIUDICE DI PACE',
#   '002 - TRIBUNALE DI IMPERIA',
#   '003 - UFFICIALI GIUDIZIARI'],
#  'ischia  ut dpna1': ['001 - PRETURA CIRCONDARIALE',
#   '002 - GIUDICE DI PACE PROCIDA',
#   '003 - GIUDICE DI PACE ISCHIA',
#   '004 - TRIB.NA SEZ. DIST. ISCHIA',
#   '005 - TRIBUNALE NA SEZ.DIS.ISCHIA'],
#  'isernia  ut dpis': ['001 - TRIBUNALE',
#   '002 - PRETURA',
#   '003 - PRETURA DI ISERNIA',
#   '004 - TRIBUNALE ISERNIA',
#   '005 - PRETURA VENAFRO',
#   '006 - GIUDICE DI PACE - ISERNIA',
#   '007 - GIUDICE DI PACE VENAFRO',
#   '008 - GIUDICE DI PACE AGNONE',
#   '009 - GIUDICE DI PACE CAROVILLI',
#   '010 - GIUDICE DI PACE FORLI DEL S.',
#   '011 - GIUDICE DI PACE FROSOLONE',
#   '012 - GIUDICE DI PACE CASTEL S. VINC',
#   '013 - TRIBUNALE DI ISERNIA',
#   '014 - PREFETTURA DI ISERNIA',
#   '015 - 80001850942',
#   '016 - NOTAIO PATALANO ALESSANDRA',
#   '017 - TRIBUNALE',
#   '018 - TRIBUNALE ISERNIA',
#   '019 - TRIBUNALE',
#   '020 - TRIBUNALE ISERNIA',
#   '021 - TRIBUNALE DI ISERNIA'],
#  'ivrea  ut dpto2': ['001 - TRIBUNALE DI IVREA',
#   '002 - PRETURA DI IVREA',
#   '003 - GIUDICE DI PACE DI IVREA',
#   '004 - GIUDICE DI PACE STRAMBINO',
#   '005 - TRIBUNALE DI IVREA',
#   "006 - GDP IVREA-EX GDP CUORGNE'",
#   '007 - GDP IVREA-EX GDP RIV. CANAVESE',
#   '008 - GDP IVREA-EX GDP CHIVASSO',
#   "009 - GDP IVREA-EX GDP CIRIE'",
#   '010 - GDP IVREA-EX GDP LANZO TOR.'],
#  'jesi  ut dpan': ['001 - PRETURA JESI',
#   '002 - TRIBUNALE ANCONA SEDE PRETURA',
#   '003 - GIUDICE DI PACE DI JESI',
#   '004 - TRIBUNALE DI FABRIANO',
#   '005 - GIUDICE DI PACE DI FABRIANO',
#   '006 - GIUDICE DI PACE DI ANCONA',
#   '007 - STRLSN54H02B474K'],
#  "l'aquila  ut dpaq": ["001 - CORTE DI APPELLO DI L'AQUILA",
#   "002 - TRIBUNALE CIVILE DI L'AQUILA",
#   "003 - PRETURA DI L'AQUILA",
#   "004 - GIUDICE DI PACE DI L'AQUILA",
#   '005 - TRIB. AMMINISTRATIVO REGIONALE',
#   "006 - TRIBUNALE PER I MINORENNI D'AB",
#   '007 - GIUDICE DI PACE DI CAPESTRANO',
#   '008 - GIUDICE DI PACE DI MONTEREALE',
#   "009 - TRIBUNALE L'AQUILA",
#   "010 - PRETURA L'AQUILA",
#   "011 - GIUDICE DI PACE L'AQUILA",
#   '012 - 9',
#   '013 - 10',
#   '014 - 11',
#   '015 - UFFICIALI GIUDIZIARI',
#   '016 - GDP AQUILA -EX GDP CAPESTRANO',
#   '017 - GDP AQUILA-EX GDP MONTEREALE',
#   '018 - TRIBSORVEGLIANZAAQ'],
#  'la spezia  ut dpsp': ['001 - TRIBUNALE DI LASPEZIA',
#   '002 - PRETURA DI LA SPEZIA',
#   '003 - UFFICIO GIUDICE DI PACE',
#   '004 - TRIBUNALE DI SARZANA',
#   '005 - GIUDICE DI PACE DI SARZANA',
#   '006 - PRETURA DI SARZANA',
#   '007 - GDP LA SP-EX GDP SARZANA'],
#  'lagonegro  ut dppz': ['001 - GIUDICE DI PACE LAURIA',
# ...
#   '004 - 1'],
#  'taormina  ut dpme': ['001 - TRIBUNALE DI TAORMINA',
#   '002 - GIUDICE DI PACE DI TAORMINA',
#   '003 - GIUDICE DI PACE FRANCAVILLA S.'],
#  'taranto  ut dpta': ['001 - TRIBUNALE DI TARANTO',
#   '002 - TRIB. DI TARANTO / GINOSA',
#   '003 - TRIB. DI TARANTO / GROTTAGLIE',
#   '004 - TRIB. DI TARANTO / MANDURIA',
#   '005 - TRIB. DI TARANTO / MARTINA F.',
#   '006 - GIUDICE DI PACE DI TARANTO',
#   '007 - GIUDICE DI PACE DI GINOSA',
#   '008 - GIUDICE DI PACE DI GROTTAGLIE',
#   '009 - GIUDICE DI PACE DI LIZZANO',
#   '010 - GIUDICE DI PACE DI MANDURIA',
#   '011 - GIUDICE DI PACE DI MARTINA F.',
#   '012 - GIUDICE DI PACE DI S. GIORGIO',
#   '013 - CORTE D APPELLO',
#   '014 - TRIBUNALE DEI MINORENNI',
#   '015 - UNEP CORTE DI APPELLO',
#   '016 - UNEP GROTTAGLIE',
#   '017 - UNEP MANDURIA',
#   '018 - UNEP GINOSA',
#   '019 - UNEP MARTINA',
#   '020 - GDP TARANTO-EX GDP GROTTAGLIE'],
#  'tempio pausania  ut dpss': ['001 - TRIBUNALE',
#   '002 - TTRIBUNALE',
#   '003 - TRIBUNALE DI TEMPIO PAUSANIA',
#   '004 - TRIBUNALE DI OLBIA',
#   '005 - TRIBUNALE DI LA MADDALENA',
#   '006 - PRETURA DI TEMPIO PAUSANIA',
#   '007 - PRETURA DI OLBIA',
#   '008 - PRETURA DI LA MADDALENA',
#   '009 - GIUDICE DI PACE DI TEMPIO P.',
#   '010 - GIUDICE DI PACE DI OLBIA',
#   '011 - GIUDICE DI PACE LA MADDALENA',
#   '012 - TEMPIO PAUSANIA'],
#  'teramo  ut dpte': ['001 - TRIBUNALE TERAMO',
#   '002 - GIUDICE DI PACE-TERAMO',
#   '003 - GIUDICE DI PACE-CAMPLI (TE)',
#   '004 - GIUDICE DI PACE-MONTORIO TE',
#   '005 - PRETURA CIRCONDARIALE TERAMO',
#   '006 - TRIBUNALE TERAMO',
#   '007 - GIUDICE DI PACE-NERETO (TE)',
#   '008 - GIUDICE DI PACE DI NOTARESCO',
#   '009 - GDP TERAMO-EX GDP ATRI',
#   '010 - GDP TERAMO EX GDP CAMPLI',
#   '011 - GDP TERAMO EX GDP GIULIANOVA',
#   '012 - GDP TERAMO-EX GDP MONT. AL V.',
#   '013 - GDP TERAMO EX GDP NERETO',
#   '014 - GDP TERAMO EX GDP NOTARESCO'],
#  'termini imerese  ut dppa': ['001 - TRIBUNALE TERMINI IMERESE',
#   '002 - GIUDICE PACE TERMINI IMERESE',
#   '003 - GIUDICE PACE MONTEMAGGIORE B.',
#   '004 - GIUDICE DI PACE DI GANGI',
#   '005 - GIUD.PACE POLIZZI GENEROSA',
#   "006 - GIUDICE DELL'ESECUZIONE",
#   "007 - TRIBUNALE SEZ.STAC.CEFALU'",
#   "008 - GIUDICE DI PACE DI CEFALU'",
#   "009 - PRETURA DI CEFALU'",
#   '010 - GDP TER. IM.-EX GDP MEZZOJUSO',
#   '011 - GDP TER. IM.-EX GDP MISILMERI',
#   '012 - GDP TE.IM.EX GDP PIANA ALBAN.'],
#  'termoli  ut dpcb': ['001 - AL113',
#   '002 - TRIBUNALE LARINO: SEZ.TERMOLI',
#   '003 - GIUDICE DI PACE DI TERMOLI',
#   '004 - GIUDICE DI PACE DI GUGLIONESI',
#   '005 - GIUDICE DI PACE DI PALATA',
#   '006 - TRIBUNALE DI LARINO',
#   '007 - GIUDICE DI PACE DI LARINO',
#   '008 - GIUDICE DI PACE CASACALENDA',
#   '009 - UFFICIALI GIUDIZIARI LARINO'],
#  'terni  ut dptr': ['001 - TRIBUNALE DI TERNI',
#   '002 - PRETURA DI TERNI',
#   '003 - PRETURA DI AMELIA',
#   '004 - GIUDICE DI PACE DI AMELIA',
#   '005 - GIUDICE DI PACE DI NARNI',
#   '006 - GIUDICE DI PACE DI TERNI'],
#  'thiene  ut dpvi': ['001 - GIUDICE DI PACE DI THIENE',
#   '002 - GIUDICE DI PACE DI ASIAGO',
#   '003 - PRETURA DI THIENE',
#   '004 - PRETURA DI ASIAGO'],
#  'tione di trento  ut dptn': ['001 - TRIBUNALE DI TN - SEZ. TIONE',
#   '002 - GIUDICE DI PACE DI TIONE'],
#  'tirano  ut dpso': ['001 - PRETURA DI TIRANO',
#   '002 - GIUDICE DI PACE',
#   '003 - GIUDICE DI PACE DI TIRANO'],
#  'tivoli  ut dprm3': ['001 - PRETURA TIVOLI',
#   '002 - TRIBUNALE TIVOLI',
#   '003 - GIUDICE DI PACE TIVOLI',
#   '004 - GIUDICE DI PACE PALOMBARA S.',
#   '005 - GIUDICE DI PACE DI SUBIACO',
#   '006 - GIUDICE DI PACE DI TIVOLI'],
#  'tolentino  ut dpmc': ['001 - TRIBUNALE DI CAMERINO',
#   '002 - GIUDICE DI PACE DI TOLENTINO',
#   '003 - GIUDICE DI PACE S. SEVERINO M.',
#   '004 - GIUDICE DI PACE DI CAMERINO',
#   '005 - CAM. ARBIT. SUSSID. TERRIT.'],
#  'tolmezzo  ut dpud': ['001 - TRIBUNALE',
#   '002 - GIUDICE DI PACE',
#   '003 - TRIBUNALE DI TOLMEZZO',
#   '004 - GIUDICE DI PACE DI PONTEBBA',
#   '005 - GIUDICE DI PACE DI TOLMEZZO',
#   '006 - TRIBUNALE TOLMEZZO CANC.VARIEB',
#   '007 - TRIBUNALE DI TOLMEZZO',
#   '008 - GDP TOLMEZZO -EX GDP PONTEBBA'],
#  'torino 1  ut dpto1': ['001 - BL219',
#   '002 - BL2193',
#   '003 - GL219',
#   '004 - EL219',
#   '005 - TRIB. TO EX TRIB. PINEROLO',
#   '006 - AL219',
#   '007 - AL2191',
#   '008 - AL2193',
#   '009 - TRIBUNALE TORINO',
#   '010 - TRIB. MINORI DI TORINO',
#   '011 - CORTE DI APPELLO TORINO',
#   '012 - GIUDICE DI PACE DI TORINO',
#   '013 - TRIBUNALE CIVILE',
#   '014 - TAR',
#   '015 - GIUDICE DI PACE DI CHIERI',
#   '016 - TRIB. DI SORVEGLIANZA TORINO',
#   '017 - GDP TORINO EX GDP CHIERI',
#   '018 - GDP TORINO -EX GDP AVIGLIANA',
#   '019 - GDP TORINO- EX GDP SUSA',
#   '020 - GDP TORINO- EX GDP MONCALIERI'],
#  'tortona  ut dpal': ['001 - TRIBUNALE DI TORTONA',
#   '002 - UFF. GIUDICE DI PACE - TORTONA',
#   '003 - PRETURA DI TORTONA',
#   '004 - 94013040061',
#   '005 - NOTAIO',
#   '006 - GNZGLC68L30I225S'],
#  'trani  ut dpbt': ['001 - GIUDICE DI PACE DI TRANI',
#   '002 - GIUDICE DI PACE DI CORATO',
#   '003 - GIUDICE DI PACE DI BISCEGLIE',
#   '004 - TRIBUNALE CIVILE DI TRANI',
#   '005 - UFFICIALE GIUDIZIARIO TRANI',
#   '006 - GDP TRANI-EX GDP MOLFETTA',
#   '007 - GDP TRANI -EX GDP RUVO D.P.',
#   '008 - TRIB.TRANI-CONTENZ.CIVILE',
#   '009 - TRIB.TRANI-VOL.GIURISDIZIONE',
#   '010 - TRIB.TRANI-PROC.FALLIMENTARI',
#   '011 - TRIB.TRANI-ESEC.MOB-IMMOB INF.',
#   '012 - TRIB.TRANI-ESEC. MOB. ANDRIA',
#   '013 - TRIB.TRANI-ESEC.MOB.MOLFETTA',
#   '014 - TRIB.TRANI-ESEC.MOB-IMMOB CART',
#   '015 - TRIB.TRANI-SEZ. PENALE',
#   '016 - TRIB.TRANI-EX SEZ. MOLFETTA',
#   '017 - TRIB.TRANI-EX SEZ. ANDRIA',
#   '018 - GDP TRANI-EX GDP CORATO'],
#  'trapani  ut dptp': ['001 - TRIBUNALE DI TRAPANI',
#   '002 - PRETURA DI TRAPANI',
#   '003 - GIUDICE DI PACE DI TRAPANI',
#   '004 - PRETURA SEZ.STACCATA ERICE',
#   '005 - GIUDICE DI PACE SEZ.STAC.ERICE',
#   '006 - GIUDICE DI PACE C.MMARE GOLFO',
#   '007 - PRETURA SEZ.STAC.ALCAMO',
#   '008 - GIUDICE DI PACE ALCAMO',
#   '009 - PRETURA DI PANTELLERIA',
#   '010 - GIUDICE DI PACE PANTELLERIA',
#   '011 - TRIB.TRAPANI SEZ. ALCAMO',
#   '012 - TRIBUNALE SEZ. STACC. ALCAMO',
#   '013 - PRETURA DI ALCAMO',
#   '014 - TRIBUNALE TRAPANI',
#   '015 - TRIBUNALE',
#   '016 - GIUDICE DI PACE DI ERICE'],
#  'trento  ut dptn': ['001 - TRIBUNALE DI TRENTO',
#   '002 - CORTE DI APPELLO DI TRENTO',
#   '003 - PRETURA DI TRENTO',
#   '004 - GIUDICE DI PACE DI TRENTO',
#   '005 - PRETURA DI MEZZOLOMBARDO',
#   '006 - GIUDICE DI PACE DI MEZZOLOMBAR',
#   '007 - GIUDICE DI PACE DI PERGINE VAL',
#   '008 - G. DI PACE CLES',
#   '009 - T.A.R. TRENTO',
#   '010 - TRIB VOLONTARIA GIURISDIZIONE',
#   '011 - ISTITUTO VENDITE GIUDIZIARIE',
#   '012 - TRIBUNALE PER I MINORENNI TN',
#   '013 - G. D. P. BORGO VALSUGANA',
#   '014 - G.D.P.TIONE TRENTO',
#   '015 - G.D.P. CAVALESE',
#   '016 - TRIB. SORVEGL. TRENTO'],
#  'trento aapp succ rimb ut dptn': ['101 - GIUDICE TAVOLARE TRENTO',
#   '102 - GIUD. TAVOLARE BORGO VALSUGANA',
#   '103 - GIUDICE TAVOLARE CAVALESE',
#   '104 - GIUDICE TAVOLARE CLES',
#   '105 - GIUD.TAVOLARE FIERA PRIMIERO',
#   '106 - GIUDICE TAVOLARE FONDO',
#   "107 - GIUDICE TAVOLARE MALE'",
#   '108 - GIUDICE TAVOLARE MEZZOLOMBARDO',
#   '109 - GIUDICE TAV.PERGINE VALSUGANA',
#   '110 - GIUD. TAVOLARE RIVA DEL GARDA',
#   '111 - GIUDICE TAVOLARE ROVERETO',
#   '112 - GIUDICE TAVOLARE TIONE'],
#  'treviglio  ut dpbg': ['001 - GIUDICE DI PACE',
#   '002 - TRIBUNALE DI TREVIGLIO'],
#  'treviso  ut dptv': ['001 - TRIBUNALE TREVISO',
#   '002 - PRETURA DI TREVISO',
#   '003 - GIUDICE DI PACE DI TREVISO',
#   '004 - PRETURA ODERZO',
#   '005 - GIUDICE DI PACE ODERZO',
#   '006 - TRIBUNALE DI TREVISO',
#   '007 - TRIBUNALE TREVISO',
#   '008 - TRIBUNALE DI TREVISO',
#   '009 - GDP TREVISO EX GDP CASTEL. V.',
#   '010 - GDP TREVISO EX GDP MONTEBELL.',
#   '011 - GDP TREVISO - EX GDP ASOLO',
#   '012 - GIUDICE PACE CONEGLIANO'],
#  'trieste  ut dpts': ['001 - TRIBUNALE DI TRIESTE',
#   '002 - PRETURA TRIESTE',
#   '003 - CORTE DI APPELLO TRIESTE',
#   '004 - GIUDICE DI PACE TRIESTE',
#   '005 - TRIB. DEI MINORI TRIESTE',
#   '006 - T A R TRIESTE',
#   '007 - TRIB. SORVEGLIANZA DI TRIESTE',
#   '101 - GIUDICE TAVOLARE DI TRIESTE'],
#  'udine  ut dpud': ['001 - TRIBUNALE DI UDINE',
#   '002 - PRETURA DI UDINE',
#   '003 - GIUDICE DI PACE DI UDINE',
#   '004 - PRETURA DI CIVIDALE DEL FRIULI',
#   '005 - GIUDICE DI PACE DI CIVIDALE',
#   '006 - PRETURA DI SAN DANIELE',
#   '007 - GIUDICE DI PACE DI SAN DANIELE',
#   '008 - PRETURA DI TARCENTO',
#   '009 - GIUDICE DI PACE DI TARCENTO',
#   '010 - PRETURA DI CODROIPO',
#   '011 - GIUDICE DI PACE DI CODROIPO',
#   '012 - UFFICIALI GIUDIZIARI DI UDINE',
#   '013 - GIUDICE DI PACE DI GEMONA',
#   '014 - TRIB. UDINE EX TOLMEZZO',
#   '015 - TRIBUNALE DI UD SEDE CIVIDALE',
#   '016 - TRIBUNALE DI UDINE SEDE N.2',
#   '017 - TRIBUNALE DI UD B CANC.VARIE',
#   '018 - TRIB. UDINE-EX PALMAN.',
#   '019 - GIUD. DI PACE UD EX LATISANA',
#   '020 - GIUD. DI PACE UD EX CERVIGNANO',
#   '021 - GIUD. DI PACE UD EX PALMANOVA',
#   '022 - TRIBUNALE B VOLONTARIA GIURISD',
#   '023 - TRIBUNALE DI CIVIDALE'],
#  'udine aapp succ rimb ut dpud': ['101 - GIUD.TAVOL. CERVIGNANO FRIULI',
#   '102 - GIUDICE TAVOLARE DI PONTEBBA'],
#  'urbino  ut dppu': ['001 - TRIBUNALE DI URBINO',
#   '002 - PRETURA DI URBINO',
#   '003 - GIUDICE DI PACE DI URBINO',
#   '004 - GIUDICE DI PACE DI CAGLI',
#   '005 - GIUDICE DI PACE DI MACERATA F.',
#   '006 - SOPRINTENDENZA URBINO',
#   '007 - 82005770415',
#   '008 - MINISTERO BENI CULTURALI',
#   '009 - 80441740588',
#   '010 - PLDMRC70M31A859W',
#   '011 - PALADINI MARCO',
#   '012 - U.N.E.P. URBINO'],
#  'valdagno  ut dpvi': ['001 - GIUDICE DI PACE DI VALDAGNO',
#   '002 - GIUDICE DI PACE DI ARZIGNANO',
#   '003 - TRIB. VICENZA SEZ. SCHIO',
#   '004 - GIUDICE DI PACE DI SCHIO'],
#  'valenza  ut dpal': ['001 - GIUDICE DI PACE DI VALENZA'],
#  'vallo della lucania  ut dpsa': ['001 - TRIBUNALE DI VALLO D/ LUCANIA',
#   '002 - PRETURA DI VALLO D/ LUCANIA',
#   '003 - PRETURA DI PISCIOTTA',
#   '004 - PRETURA DI SAPRI',
#   '005 - GIUDICE DI PACE DI VALLO D/ L.',
#   '006 - GIUDICE DI PACE PISCIOTTA',
#   '007 - GIUDICE DI PACE DI SAPRI',
#   '008 - TRIB.LE SALA CONS.NA SEZ.SAPRI',
#   '009 - PRETURA DI AGROPOLI',
#   '010 - GIUDICE DI PACE DI AGROPOLI',
#   '011 - PRETURA DI CAPACCIO',
#   '012 - GIUDICE DI PACE DI CAPACCIO'],
#  'varese  ut dpva': ['001 - TRIBUNALE DI VARESE',
#   '002 - PRETURA DI VARESE',
#   '003 - GIUDICE DI PACE DI VARESE',
#   '004 - GDP VARESE-EX GDP GAVIRATE'],
#  'vasto  ut dpch': ['001 - TRIBUNALE DI VASTO',
#   '002 - PRETURA DI VASTO',
#   '003 - GIUDICE DI PACE VASTO',
#   '004 - GIUDICE DI PACE CASALBORDINO',
#   '005 - GIUDICE DI PACE GISSI',
#   '006 - GIUDICE DI PACE CASTIGLIONE M',
#   '007 - GDP VASTO EX GDP CASALBORDINO',
#   '008 - GDP VASTO EX GDP CAST.M. M.',
#   '009 - GDP VASTO EX GDP GISSI'],
#  'velletri  ut dprm3': ['001 - PRETURA',
#   '002 - TRIBUNALE VELLETRI',
#   '003 - GIUDICI DI PACE DI VELLETRI',
#   '004 - GIUDICI DI PACE SEGNI'],
#  'venezia 1  ut dpve': ['001 - TRIBUNALE DI VENEZIA',
#   '002 - PRETURA DI VENEZIA',
#   '003 - CORTE APPELLO DI VENEZIA',
#   '004 - GIUDICE DI PACE DI VENEZIA',
#   '005 - TRIBUNALE MINORENNI VE',
#   '006 - T.A.R. VENETO',
#   '007 - T.R.A.P. - C.A. VE',
#   '008 - SEZ.MINORI CORTE APPELLO VE',
#   '009 - VOLONTARIA GIURISDIZ. TRIB',
#   '010 - REPERTORIO SICC. TRIB. VE',
#   '011 - TRIB. VE - S.D. CHIOGGIA',
#   '012 - TRIB. VE - S.D. DOLO',
#   '013 - TRIB. VE - S.D. DOLO REP. SICC',
#   '014 - TRIB. VE - S.D. MESTRE',
#   "015 - TRIB. VE - S.D. S. DONA' PIAVE",
#   '016 - G. DI PACE CAVARZERE',
#   '017 - G. DI PACE CHIOGGIA',
#   '018 - G. DI PACE DOLO',
#   '019 - G. DI PACE MESTRE',
#   "020 - G. DI PACE S. DONA' DI PIAVE",
#   '021 - TRIB. MINORI MESTRE'],
#  'venezia 2  ut dpve': ['001 - GIUDICE DI PACE MESTRE',
#   '002 - TRIBUNALE DOLO',
#   '003 - GIUDICE DI PACE DOLO',
#   '004 - TRIBUNALE MESTRE',
#   '005 - SICC. TRIBUNALE DI DOLO',
#   '006 - TRIBUNALE DI MESTRE',
#   '007 - TRIB. MINORENNI MESTRE'],
#  'verbania  ut dpvb': ['001 - TRIBUNALE',
#   '002 - PRETURA DI VERBANIA',
#   '003 - PRETURA DI ARONA',
#   '004 - PRETURA DI OMEGNA',
#   '005 - GIUDICE DI PACE DI VERBANIA',
#   '006 - GIUDICE DI PACE DI OMEGNA',
#   '007 - TRIBUNALE DI VERBANIA STRALCIO',
#   '008 - TRIBUNALE DI VERBANIA',
#   '009 - TRIBUNALE DI VERBANIA',
#   '010 - TRIBUNALE',
#   '011 - TRIBUNALE DI VERBANIA',
#   '012 - TRIBUNALE DOMODOSSOLA',
#   '013 - GIUDICE DI PACE DI DOMODOSSOLA'],
#  'vercelli  ut dpvc': ['001 - TRIBUNALE DI VERCELLI',
#   '002 - PRETURA DI VERCELLI',
#   '003 - GIUDICE DI PACE DI TRINO',
#   '004 - GIUDICE DI PACE DI VERCELLI',
#   '005 - TRIBUNALE VERCELLI S. STRALCIO',
#   '006 - TRIB.VERCELLI SEZ.C.MONFERRATO',
#   '007 - NON PRESENTE',
#   '008 - NON PRESENTE',
#   "009 - GIUDICE DI PACE DI SANTHIA'"],
#  'verolanuova  ut dpbs': ['001 - GIUDICE DI PACE DI VEROLANUOVA'],
#  'verona 2  ut dpvr': ['001 - TRIBUNALE DI VERONA',
#   '002 - PRETURA DI VERONA',
#   '003 - GIUDICE DI PACE DI VERONA',
#   '004 - GIUDICE PACE DI ISOLA D. SCALA',
#   '005 - PRETURA DI ISOLA DELLA SCALA',
#   '006 - CORTE MILITARE APPELLO VERONA',
#   '007 - GIUDICE DI PACE CAPRINO V.SE',
#   '008 - PRETURA DI CAPRINO VERONESE',
#   '009 - GDP VERONA - EX GDP SOAVE',
#   '010 - GIUDICE DI PACE DI LEGNAGO'],
#  'viareggio  ut dplu': ['001 - TRIBUNALE DI VIAREGGIO',
#   '002 - GIUDICE DI PACE VIAREGGIO',
#   '003 - PRETURA DI PIETRASANTA',
#   '004 - GIUDICE DI PACE DI PIETRASANTA',
#   '005 - GIUDICE DI PACE DI VIAREGGIO',
#   '006 - GIUDICE DI PACE DI VIAREGGIO'],
#  'vibo valentia  ut dpvv': ['001 - GIUDICE DI PACE MILETO',
#   '002 - GIUDICE DI PACE VIBO VALENTIA',
#   '003 - GIUDICE DI PACE DI NICOTERA',
#   '004 - TRIBUNALE DI VIBO VALENTIA',
#   '005 - GIUDICE DI PACE PIZZO',
#   '006 - GIUDICE DI PACE DI FILADELFIA',
#   '007 - PRETURA DI VIBO VALENTIA',
#   '008 - GIUDICE DI PACE TROPEA',
#   '009 - SEZ. STACCATA PRETURA TROPEA',
#   '010 - REGIONE CALABRIA ASSESSORATO',
#   '011 - TRIBUNALE SEZ. TROPEA',
#   '012 - GIUDICE DI PACE DI ARENA',
#   '013 - GIUDICE DI PACE SERRA S. BRUNO',
#   '014 - PRET. VIBO V SEZ. SERRA S.BRU',
#   '015 - GIUDICE DI PACE SORIANO CAL.',
#   '016 - TRIBUN ARBITR-SEZ. STEFANACONI',
#   '017 - PRET. VIBO V. SEZ. SERRA S. BR',
#   '018 - HIPPONION CONCILIA SEZ. V.V.'],
#  'vicenza  ut dpvi': ['001 - TRIBUNALE DI VICENZA',
#   '002 - PRETURA DI VICENZA',
#   '003 - GIUDICE DI PACE DI VICENZA',
#   '004 - ISTITUTO VENDITE GIUDIZIARIE',
#   '005 - UFFICIALI GIUDIZIARI VICENZA',
#   '006 - GIUDICE DI PACE DI LONIGO',
#   '007 - GDP VICENZA - EX GDP THIENE',
#   '008 - GDP VICENZA - EX GDP ARZIGNANO',
#   '009 - GDP VICENZA - EX GDP VALDAGNO'],
#  'vicenza 1  ut dpvi': ['001 - TRIBUNALE DI VICENZA',
#   '002 - PRETURA DI VICENZA',
#   '003 - GIUDICE DI PACE DI VICENZA',
#   '004 - ISTITUTO VENDITE GIUDIZIARIE',
#   '005 - UFFICIALI GIUDIZIARI VICENZA',
#   '006 - GIUDICE DI PACE DI LONIGO',
#   '007 - GDP VICENZA - EX GDP THIENE',
#   '008 - GDP VICENZA - EX GDP ARZIGNANO',
#   '009 - GDP VICENZA - EX GDP VALDAGNO'],
#  'vicenza 2  ut dpvi': ['00E - E', '000 - 0'],
#  'vigevano  ut dppv': ['001 - PRETURA',
#   '002 - TRIBUNALE',
#   '003 - GIUDICE DI PACE',
#   '004 - ISTITUTO VENDITE GIUDIZIARIE',
#   '005 - UFFICIO UNICO DEL TRIBUNALE',
#   '006 - COMMISSIONE TRIBURARIA PROVINC',
#   '007 - TRIBUNALE',
#   '008 - TRIBUNALE',
#   '009 - GIUDICE DI PACE',
#   '010 - GDP VIGEV-EX GDP ABBIATEGRAS.',
#   '011 - GDP VIGEV-EX GDP MEDE',
#   '012 - GDP VIGEV.-EX GDP MORTARA'],
#  'viterbo  ut dpvt': ['001 - PRETURA DI VITERBO',
#   '002 - TRIBUNALE VITERBO',
#   '003 - TRIB. SEZIONE MONTEFIASCONE',
#   '004 - TRIB. SEZ. CIVITA CASTELLANA',
#   '005 - GIUD. DI PACE VITERBO',
#   '006 - GIUD. DI PACE C.CASTELLANA',
#   '007 - GIUD. DI PACE MONTEFIASCONE',
#   '008 - GIUD. DI PACE VALENTANO',
#   '009 - GIUD. DI PACE RONCIGLIONE',
#   '010 - PRETURA DI CIVITA CASTELLANA',
#   '011 - PRETURA DI MONTEFIASCONE',
#   '012 - TRIBUNALE VITERBO'],
#  'vittoria  ut dprg': ['001 - GIUDICE DI PACE DI VITTORIA',
#   '002 - GIUDICE DI PACE DI COMISO',
#   '003 - TRIB. RG SEZ. STACC. VITTORIA',
#   '004 - TRIB. RAGUSA EX PRETURA COMISO',
#   '005 - TRIB.RG. SEZ. VITTORIA N.E.P.',
#   '006 - DI PORTO DI POZZALLO'],
#  'vittorio veneto  ut dptv': ['001 - PRETURA VITTORIO VENETO',
#   '002 - GIUDICE PACE VITTORIO VENETO'],
#  'voghera  ut dppv': ['001 - TRIBUNALE',
#   '002 - TRIBINALE DI VOGHERA',
#   '003 - GIUDICE DI PACE DI VOGHERA',
#   '004 - GIUDICE DI PACE DI CASTEGGIO'],
#  'zogno  ut dpbg': ['001 - GIUDICE DI PACE DI ZOGNO']}
